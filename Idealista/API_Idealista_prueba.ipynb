# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("api_key")
secret = os.getenv("secret")

# %%
from utils_idealista import idealista_token, query

token, expires = idealista_token(api_key, secret)

filter_request = {
    "country": "es",
    "operation": "sale",
    "propertyType": "homes",
    "locationId": "0-EU-ES-28",
    "maxItems": 50 
    
}

response = query(token, filter_request)

# %%
token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTc1Mzc2NTIxMiwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMGMzNjdhYTUtMDg5OS00ZTQyLTk1ZDMtYWRlNDcyZGU5YTUwIiwiY2xpZW50X2lkIjoidDV5aXMzdWM5bm9iZm1lMHVxYXEwN2JieGhzNmIyd28ifQ.Nosng2MhqRVPHDtGJR4E656Ty5CdzhGHfv_tpwhoJiw'

# %%
response
# Out:
# {'elementList': [{'propertyCode': '107203987',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/95/ed/45/1311342091.webp',
#    'externalReference': 'V7159I',
#    'numPhotos': 31,
#    'floor': '3',
#    'price': 1550000.0,
#    'priceInfo': {'price': {'amount': 1550000.0, 'currencySuffix': '€'}},
#    'propertyType': 'penthouse',
#    'operation': 'sale',
#    'size': 158.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'camino de los Jardines, 7',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'La Moraleja urbanización',
#    'country': 'es',
#    'latitude': 40.5071718,
#    'longitude': -3.6087171,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/107203987/',
#    'description': 'Venta. Piso. La Moraleja. Promora ofrece excepcional piso a estrenar en la prestigiosa comunidad “ The Garden La Moraleja “, la urbanización se distingue por sus instalaciones de lujo diseñadas para el disfrute y el bienestar de sus residentes, amplias piscina con iluminación nocturna, rodeadas de jardines, espacio con sofás rodeados de vegetación, spa y sauna. Tres dormitorios con dos baños y aseo.   La distribución es la siguiente: hall de entrada, salón y cocina abierta con tendedero y aseo. Tiene 3 dormitorios con 2 baños, el dormitorio principal con baño incorporado en suite.  Aire acondicionado. Calefacción por aerotermia.  Dos plazas de garaje.  Trastero.  Excelente urbanización con dos piscinas, sauna, spa y zonas deportivas.  Probablemente La Moraleja sea la urbanización residencial de lujo más conocida de España. Los muchos personajes famosos que la han elegido como residencia habitual son responsables de su importante presencia mediática. Situada al norte de Madrid, en el término municipal de Alcobendas, tiene una extensión de 950 hectáreas. Cuenta con 1050 viviendas independientes sobre parcelas de 1.500, 2.500 y 10.000 m2 y con 400 adosados en 9 urbanizaciones diferentes. Tanto su estratégica ubicación -a un paso del centro de la capital (12km) y a escasos kilómetros del aeropuerto de Barajas (5km)- como sus férreas medidas de seguridad y sus muchas opciones de escolarización privada, ocio, deporte y salud, han convertido La Moraleja en un referente residencial en nuestro país.  Junto a las urbanizaciones de El Soto y El Encinar, conforman un núcleo geográfico de similares características demográficas. Su código postal es el 28109. Es aquí, en la plaza de La Moraleja (junto a la farmacia), donde Promora atiende a los clientes que quieren acceder a las viviendas de la zona norte de Madrid. Puedes ver más inmuebles en nuestra página web.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 9810.0,
#    'change': {},
#    'detailedType': {'typology': 'flat', 'subTypology': 'penthouse'},
#    'suggestedTexts': {'subtitle': 'La Moraleja urbanización, La Moraleja',
#     'title': 'Ático en camino de los Jardines, 7'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108816285',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/a7/b1/9e/1356236609.webp',
#    'externalReference': 'VG-212295',
#    'numPhotos': 32,
#    'floor': 'bj',
#    'price': 1250000.0,
#    'priceInfo': {'price': {'amount': 1250000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 166.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'paseo de los Parques',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'Encinar de los Reyes',
#    'country': 'es',
#    'latitude': 40.5111465,
#    'longitude': -3.6527442,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108816285/',
#    'description': 'Gilmar Consulting Inmobiliario, ofrece en exclusiva, luminoso y espacioso piso de tres dormitorios y amplia terraza con gran jardín en una de las mejores urbanizaciones de El Encinar de los Reyes. Tiene una ubicación inigualable a pasos de La Plaza de la Moraleja y del Centro Comercial El Encinar. Se encuentra dentro de una urbanización privada, con los mejores servicios como piscina exterior para adultos y niños, pádel, zonas comunes de paseo y seguridad física 24h con estricto control de acceso. Iniciando su recorrido, nos da la bienvenida un luminoso salón-comedor con acceso a la terraza exterior y a un jardín de 136 metros. Cuenta con cocina independiente, con mobiliario y electrodomésticos; así como tendedero techado con área de lavandería. En el área de descanso, se distribuyen dos fantásticos dormitorios con armarios empotrados y dos baños completos; el de la habitación principal en suite.  El piso cuenta con un apartamento independiente con acceso desde la cocina. Consta de un dormitorio con baño en suite, gran trastero y acceso a las dos plazas de garaje. La Moraleja, compuesta por La Moraleja, El Soto y El Encinar de los Reyes, es el área residencial de lujo por excelencia de Madrid y la más conocida de España, situada en la zona Norte de Madrid. Según algunas publicaciones de prestigio, es la mejor urbanización del mundo, teniendo en cuenta sus cualidades.  Está situada a 15 minutos del centro de Madrid y a 10 minutos de la Terminal Internacional 4 del Aeropuerto Adolfo Suárez.  La Moraleja cuenta con el mayor número de colegios privados nacionales e internacionales de toda España (entre otros el International College Spain, King’s College, San Patricio, Runnymede, Los Sauces, Brains, Santa Helena, Saint George, Highlands, Aldovea, Liceo Europeo, etc…) Acoge además uno de los dos campus que la Universidad Europea de Madrid tiene en la Comunidad de Madrid.  La zona tiene gran cercanía al Parque Forestal de Valdebebas, el segundo más grande de Madrid), varios centros comerciales, supermercados, hospitales, centros médicos, dos campos de golf de 18 hoyos, club de tenis, club de pádel, y una de las ofertas gastronómicas más atractivas de Madrid.  Hay que destacar La Plaza de la Moraleja, donde se encuentran los principales y más prestigiosos restaurantes de Madrid (A’Kangas, Áurea, La Máquina, La Penela, El Barril, Sushi 99, Peppe Fusco) Cafeterías (Café Pino, Panod), farmacias, panaderías, bancos etc… Es un área que goza de gran seguridad gracias al sistema de alarmas que está conectado con la Entidad de Conservación de La Moraleja y las garitas de seguridad ubicadas en las diferentes entradas de acceso a la zona. ¡Vivir en la Moraleja significa calidad, exclusividad y comodidad en un entorno inigualable!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 7530.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Encinar de los Reyes, La Moraleja',
#     'title': 'Piso en paseo de los Parques'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106702840',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/2d/e6/4f/1297219632.webp',
#    'externalReference': 'PV8891I',
#    'numPhotos': 51,
#    'floor': '2',
#    'price': 1335000.0,
#    'priceInfo': {'price': {'amount': 1335000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 157.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'calle del Carril de los Caleros',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Moncloa',
#    'country': 'es',
#    'neighborhood': 'Aravaca',
#    'latitude': 40.4602576,
#    'longitude': -3.7968684,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106702840/',
#    'description': 'Impecable piso de 157 m² con terraza de 130 m² en venta en urbanización cerrada con piscina. En buenísima ubicación por cercanía a zona comercial y de ocio, servicios y bien comunicada por transporte público y principales carreteras. Distribución: · Amplio hall de recibo. · Aseo de visitas. · Armario gabanero. · Cocina office con tendedero y salida a terraza. · Salón comedor con salida a terraza. · Dos dormitorios. · Baño completo. · Dormitorio principal con vestidor y baño completo. Puedes ver más inmuebles en nuestra página web. Entre el Monte del Pardo y la Casa de Campo, y a tan solo 9 kilómetros del centro de Madrid, Aravaca es un lugar privilegiado: ofrece todo lo que un ciudadano necesita en una gran urbe, y además está perfectamente comunicada con la capital gracias a la autopista A-6, la M-500, la M-503 (carretera de Castilla), M-30 y M-40. Cuenta con múltiples instalaciones deportivas, tiendas, restaurantes, academias, institutos, así como con los colegios más prestigiosos de Madrid. Es un área con mucho encanto donde sus 23.000 habitantes disfrutan de las ventajas de vivir en una gran ciudad, y a su vez de la tranquilidad de estar en un pueblo donde pasear, ir de compras caminando, e incluso ir en bici hasta el centro de Madrid o Ciudad Universitaria a través de la Casa de Campo.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 8503.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Aravaca, Madrid',
#     'title': 'Piso en calle del Carril de los Caleros'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '107999491',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/60/75/61/1352741728.webp',
#    'externalReference': 'PV9078I',
#    'numPhotos': 49,
#    'floor': 'bj',
#    'price': 2250000.0,
#    'priceInfo': {'price': {'amount': 2250000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 188.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 4,
#    'address': 'avenida de Luis García Cereceda',
#    'province': 'Madrid',
#    'municipality': 'Pozuelo de Alarcón',
#    'district': 'Zona Prado de Somosaguas - La Finca',
#    'country': 'es',
#    'neighborhood': 'La Finca',
#    'latitude': 40.406757,
#    'longitude': -3.7982987,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/107999491/',
#    'description': 'Exclusivo bajo con jardín de esquina, con piscina privada, en la exclusiva urbanización de La Finca LGC3. La vivienda está orientada al sur por lo que goza de una maravillosa luz. Vistas al recién inaugurado campo de golf de 18 hoyos, cuenta con 339 m² construidos, de los cuales 188 m² son de vivienda, y 137 m² de terraza y piscina privada. Disfruta de un jardín privado de 147 m² con acceso a las zonas comunes, y un agradable porche. En un enclave único, en una de las urbanizaciones más seguras de Europa, con un sistema férreo de seguridad, cerrada y vigilada 24 horas. En magnífica ubicación por su cercanía al centro comercial Grand Café de La Finca, y de colegios internacionales como el Colegio Británico o el Americano. Bien comunicada por transporte público y con fácil acceso con carreteras principales.  Distribución: · Amplio hall de recibo, baño completo y armario gabanero. · Salón comedor. · Cocina oficce con isla central semi-integrada a través de unas puertas correderas con cuarterones diseñada específicamente para esta vivienda. Ambas estancias tienen salida al porche y al jardín. · En la zona de dormitorios encontramos un amplio frente de armarios para ropa blanca y almacenaje. · Dormitorio con baño en suitte. · Dormitorio con baño en suitte. · Dormitorio principal con baño en suitte y vestidor. · Zona de lavado plancha independiente. · Dormitorio de servicio. Dos plazas de garaje y trastero. Puedes ver más inmuebles en nuestra página web. A La Finca se la conoce como la urbanización más segura de toda Europa. Es muy demandada, además, por su privacidad y el cuidado exquisito de sus zonas comunes. Como rasgo de estilo, posee maravillosos lagos y jardines, así como una arquitectura perfectamente estudiada y uniforme, que podemos ver en sus pisos, adosados, pareados y chalets independientes. Situada en el término municipal de Pozuelo de Alarcón, La Finca se halla muy bien comunicada por la M-40 y la carretera de Castilla. Tiene también varias líneas de autobuses, metro ligero y tren de cercanías.  Cuenta con un club deportivo, restaurantes y un centro comercial que cubre todas las necesidades de sus residentes. En sus inmediaciones encontramos algunos de los mejores colegios de Madrid y se halla a tan solo 5 minutos de Pozuelo.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 11968.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'La Finca, Pozuelo de Alarcón',
#     'title': 'Piso en avenida de Luis García Cereceda'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106010517',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/4e/70/35/1351929883.webp',
#    'externalReference': 'PV8838I',
#    'numPhotos': 46,
#    'price': 3950000.0,
#    'priceInfo': {'price': {'amount': 3950000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 1900.0,
#    'rooms': 7,
#    'bathrooms': 10,
#    'address': 'calle Línea',
#    'province': 'Madrid',
#    'municipality': 'Pozuelo de Alarcón',
#    'district': 'Zona Pueblo',
#    'country': 'es',
#    'neighborhood': 'Zona Pueblo',
#    'latitude': 40.4462524,
#    'longitude': -3.8173481,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106010517/',
#    'description': 'Chalet independiente de 1.900 m² con parcela de 5.900 m² en Pozuelo. Distribución: PLANTA BAJA: - Hall de acceso, dos aseos de cortesía. - Distribuidor central con piscina interior climatizada con fuente y jacuzi. - Salón con bar inglés. - Comedor. - Cocina y zonas de servicio (dormitorio con baño y zona de plancha). - Cuatro dormitorios tipo suite, con vestidor completo y baño integrado en la disposición de la habitación, con bañera y ducha independiente.  - Zona de gimnasio, comunicada con la habitación principal, con vestuarios, duchas, sauna, baño turco y sala de aparatos. PLANTA PRIMERA:  - Un dormitorio tipo suite, con vestidor completo y baño integrado en la disposición de la habitación, con bañera y ducha independiente, con terraza privada y estancias diáfanas de biblioteca y zona de pintura.  - Aseo de cortesía.  - Doble altura en sobre hall y salón, iluminados por cúpula cenital.  - Terrazas accesibles (preparadas para posibles ampliaciones, tanto estructuralmente como con preinstalación de todo tipo de instalaciones (agua, luz, telefonía, etc)). PLANTA SÓTANO: - Sala polivalente con barra de bar, bolera profesional y galería de tiro con arco (preparado como bunker, con todas las acometidas).  - Dormitorio de servicio y baño completo. - Taller de reparaciones y laboratorio fotográfico y cuartos varios de instalaciones. PLANTA TÉCNICA:  - Bajo la totalidad de la planta baja, cámara practicable de entre uno y dos metros de altura donde se alojan las instalaciones generales incluidas las de la piscina interior, hasta un total de 800 m². Todas las plantas están comunicadas entre si por escalera y ascensor. Aparcamiento cubierto en planta baja, junto a la entrada con capacidad para ocho vehículos. Jardín arbolado, con piscina, terraza exterior, barbacoa y caseta para perros.  Puedes ver más inmuebles en nuestra página web. Este importante municipio de Madrid ocupa una extensión de 42 km2 y tiene una población de aproximadamente 84.000 habitantes. Como referencia geográfica, se encuentra a 11 kilómetros del centro de la capital y linda con Aravaca. Además de varias líneas de autobuses y de metro ligero, cuenta con dos estaciones de cercanías: una en Pozuelo y otra en El Barrial, junto al Corte Inglés. Sin olvidar sus tres grandes ejes: la A-6, la M-500 y la M-40.  De entres sus muchas urbanizaciones, destacamos La Finca, Somosaguas o Álamos de Bularas. Según su carácter urbanístico, en algunas se han construido pisos cerca de las zonas comerciales, y en otras, adosados y chalets independientes.  Asimismo, cuenta con colegios muy conocidos, algunos de ellos bilingües, lo que hace de esta población una zona muy demandada por ejecutivos destinados en Madrid. En sus inmediaciones se encuentra el Campus Universitario de Somosaguas, donde se cursan varias carreras de la Universidad Complutense.  Estamos ante una zona muy tranquila, de gran seguridad y con unos servicios acordes a la gran ciudad que es hoy día. De hecho, desde hace ya unos años tiene teatro y su propio conservatorio.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 2079.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Zona Pueblo, Pozuelo de Alarcón',
#     'title': 'Casa independiente en calle Línea'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106349275',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/a3/c1/5a/1281719993.webp',
#    'externalReference': 'PV8839I',
#    'numPhotos': 66,
#    'price': 2975000.0,
#    'priceInfo': {'price': {'amount': 2975000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 818.0,
#    'rooms': 6,
#    'bathrooms': 6,
#    'address': 'calle Transversal 1',
#    'province': 'Madrid',
#    'municipality': 'Pozuelo de Alarcón',
#    'district': 'Urbanizaciones',
#    'country': 'es',
#    'neighborhood': 'Montealina',
#    'latitude': 40.4227208,
#    'longitude': -3.8426658,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106349275/',
#    'description': 'Fantástico chalet independiente de 818 m² en fantástica parcela de esquina de 3.603 m² diseñada con grandes espacios comunicados y abiertos al jardín. Con fantástica parcela con piscina, zona de barbacoa, horno de piedra y bonito jardín consolidado.  Distribución: PLANTA PRINCIPAL: - Hall de entrada. - Despacho con salida al jardín. - Amplio salón con salida al jardín  - Comedor con salida al jardín. - Cocina de gran tamaño, totalmente reformada, con zona de office. - Zona de lavado. - Apartamento de servicio con baño y acceso independiente. - Aseo de invitados. - Armario ropero. PRIMERA PLANTA: - Dormitorio principal en suite de gran tamaño con baño y vestidor. - Dormitorio con baño en suite. - Dos amplias habitaciones dobles de buen tamaño. - Baño completo. - Dormitorio con baño con suite. PLANTA BAJA:  - Salón con billar. - Despensa. - Zona de maquinas. - Trastero. - Bodega. - Garaje con capacidad para tres coches. Puedes ver más inmuebles en nuestra página web. Urbanización de lujo muy consolidada, de acceso cerrado y vigilancia las 24 horas. Pertenece al municipio de Pozuelo de Alarcón y ofrece un maravilloso paisaje donde se encuentra el bosque protegido de Boadilla del Monte.  Conectada por la M-40 y la M-500, tiene transporte público, y un fácil acceso a la zona comercial de Pozuelo. Como rasgo distintivo, todas las viviendas son chalets independientes en muy buenas parcelas de gran privacidad.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 3637.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Montealina, Pozuelo de Alarcón',
#     'title': 'Casa independiente en calle Transversal 1'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108212506',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/d7/21/4d/1337699789.webp',
#    'externalReference': 'LO-209361',
#    'numPhotos': 34,
#    'price': 1795000.0,
#    'priceInfo': {'price': {'amount': 1795000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 260.0,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'calle del Padre Arrupe',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'Encinar de los Reyes',
#    'country': 'es',
#    'latitude': 40.5027596,
#    'longitude': -3.6371706,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108212506/',
#    'description': 'Gilmar Moraleja Consulting te invita descubrir EN EXCLUSIVA esta espectacular casa pareada en una urbanización cerrada con seguridad 24 horas, ubicada en la exclusiva zona de El Encinar de los Reyes. Con un diseño funcional y acogedor, esta propiedad de 260 m² construidos se distribuye en dos plantas que ofrecen un ambiente perfecto para disfrutar en familia. En la planta baja, te recibe un hall de entrada que da paso a un amplio salón comedor, ideal para momentos inolvidables. La cocina, equipada con zona de office y acceso directo al jardín, es perfecta para los amantes de la gastronomía. Además, cuenta con un baño completo que añade comodidad a este nivel.  Subiendo a la planta primera, encontrarás dos generosos dormitorios secundarios, que pueden unirse para crear un espacio aún más amplio. La habitación principal destaca por su tamaño y cuenta con un baño en suite que garantiza privacidad y confort. Un baño secundario compartido completa esta planta. La propiedad también incluye plaza de garaje para dos vehículos y un gran trastero, ofreciendo soluciones de almacenamiento adicionales y instalación de fotovoltaica individual en cubierta con posibilidad de instalar acumuladores. Los servicios de la urbanización son excepcionales: disfruta de dos piscinas (adultos y niños), pistas de pádel y tenis, un parque infantil y amplias zonas ajardinadas donde los más pequeños pueden jugar y explorar. Esta casa está lista para convertirse en tu nuevo hogar. No pierdas la oportunidad de vivir en un entorno seguro y tranquilo, rodeado de naturaleza y comodidades. ¡Ven a visitarla y enamórate! La Moraleja es el área residencial de lujo por excelencia de Madrid y la más conocida de España. Se sitúa en la zona Norte de la capital y está compuesta por La Moraleja, El Soto de la Moraleja y El Encinar de los Reyes. Según algunas publicaciones de prestigio mundial, La Moraleja es la mejor urbanización del mundo, teniendo en cuenta sus cualidades: situada a 10 minutos del centro de Madrid y a 5 minutos de la Terminal Internacional 4 del Aeropuerto Adolfo Suárez Barajas, en el término municipal de Alcobendas. Tiene una extensión de 950 hectáreas, con 1.050 viviendas independientes sobre parcelas de 1.500, 2.500 y 10.000 m2 y con 400 chalets adosados en nueve urbanizaciones diferentes. La Moraleja cuenta con el mayor número de colegios privados nacionales e internacionales de toda España, entre otros, el International College, King’s College, San Patricio, Runymede, Los Sauces, Brains, Saint George, Highlands, Aldovea, Liceo Europeo…. Acoge además uno de los dos campus que la Universidad Europea de Madrid tiene en la Comunidad de Madrid. Cuenta asimismo con varios centros comerciales y médicos, dos campos de golf de 18 hoyos, club de tenis, club de paddle, y una de las ofertas gastronómicas más atractivas de Madrid. Hay que destacar La Plaza de la Moraleja, donde se encuentran los principales y más prestigiosos restaurantes de Madrid (A’Kangas, La Máquina, Aurea, La Penela, Sushi99), cafeterías como Pino, Embassy o farmacia y bancos. La Moraleja es un área que goza de gran seguridad gracias al sistema de alarmas que está conectado con la Entidad de Conservación de La Moraleja y las garitas de seguridad ubicadas en las diferentes entradas de acceso a la zona. Vivir en la Moraleja significa calidad, exclusividad y comodidad en un entorno inigualable y con los mejores servicios.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 6904.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'semidetachedHouse'},
#    'suggestedTexts': {'subtitle': 'Encinar de los Reyes, La Moraleja',
#     'title': 'Chalet pareado en calle del Padre Arrupe'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '104306965',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/aa/c2/63/1217034679.webp',
#    'externalReference': 'JM195047 ',
#    'numPhotos': 53,
#    'price': 15000000.0,
#    'priceInfo': {'price': {'amount': 15000000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 1700.0,
#    'rooms': 8,
#    'bathrooms': 11,
#    'address': 'paseo de la Marquesa Viuda de Aldama',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'La Moraleja urbanización',
#    'country': 'es',
#    'latitude': 40.5144704,
#    'longitude': -3.634451,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104306965/',
#    'description': 'GILMAR MORALEJA tiene el honor de presentar esta maravillosa villa provenzal en La Moraleja. Trasladarse a la Provenza francesa sin salir de Madrid es posible, gracias a esta espectacular propiedad de 10.000 m2 situada en La Moraleja.    Este chalet independiente de estilo provenzal es un verdadero paraíso de lujo y elegancia, con una superficie construida de 1.700 m2 distribuidos en dos plantas y un sótano. Al adentrarse en esta impresionante vivienda, se puede apreciar la calidad y la atención al detalle en cada rincón. Los materiales utilizados, como la piedra, la madera y el metal, crean una atmósfera lujosa y sofisticada.  El magnífico hall de entrada de 62 m2 da la bienvenida a los visitantes, mientras que el espacioso salón de 70 m2, con grandes ventanales y una imponente chimenea, se convierte en el corazón de la casa.  El comedor de 40 m2, conectado directamente con el salón, es perfecto para celebrar grandes banquetes.  Además, la propiedad cuenta con un fabuloso salón biblioteca, con majestuosas columnas de piedra, chimenea y vigas de madera vista, que lo convierten en uno de los espacios más especiales de la casa. En la planta principal también se encuentra la cocina, de estilo provenzal y completamente equipada, con despensa y zona de lavandería.  El dormitorio principal, con 21 m2, cuenta con vestidor, baño en suite y unas vistas impresionantes al jardín. En la primera planta se encuentran cinco amplias habitaciones, todas ellas con baño en suite y algunas con acceso a una terraza.  Además, hay un cuarto de estar que ofrece un espacio adicional para relajarse y disfrutar de momentos de tranquilidad. El exterior de la vivienda cuenta con un bonito porche y un jardín de una hectárea, cuidado con esmero y en perfecta armonía con la fachada de la casa. El jardín cuenta con un magnífico arbolado y una vegetación exuberante, así como una preciosa fuente. Los residentes podrán disfrutar del aire libre y de momentos de relax en este entorno idílico.   La propiedad cuenta con una piscina cubierta climatizada, perfecta para disfrutar durante todo el año en edificación individual dentro de la parcela de 10.000 m2. La Moraleja es una de las zonas más exclusivas de Madrid, conocida por sus amplias y lujosas propiedades. Este barrio residencial ofrece una gran calidad de vida, con amplias zonas verdes, seguridad privada y una gran oferta de servicios y actividades.  Además, cuenta con excelentes conexiones de transporte, con varias líneas de autobús cercanas y la estación de metro más cercana a menos de 10 kilómetros. En cuanto a la oferta educativa, La Moraleja cuenta con varios colegios de prestigio a menos de 10 kilómetros, como el International College of Spain (ICS), Colegio San Patricio, King´s College, el Liceo Europeo de Madrid y otros 10 colegios mas de altísimo prestigio.  Para ir de compras, los residentes encontrarán el Corte Inglés y el Centro Comercial Moraleja Green a pocos minutos en coche. Gilmar es una reconocida compañía inmobiliaria con más de 35 años de experiencia en el sector.  Desde 1983, Gilmar ha ayudado a sus clientes a encontrar la casa de sus sueños, ofreciendo un servicio personalizado y profesional. Si desea más información sobre esta propiedad, no dude en ponerse en contacto con nuestro equipo en la oficina de La Moraleja, ubicada en Plaza de la Moraleja, s/n. Puede llamar al o enviar un correo electrónico.  Recuerde facilitarnos la referencia MOV02961 para obtener más detalles sobre este increíble chalet en La Moraleja.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 8824.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'La Moraleja urbanización, La Moraleja',
#     'title': 'Casa independiente en paseo de la Marquesa Viuda de Aldama'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106006394',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/37/68/65/1272948906.webp',
#    'externalReference': 'VG-198000',
#    'numPhotos': 62,
#    'floor': '3',
#    'price': 1850000.0,
#    'priceInfo': {'price': {'amount': 1850000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 312.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 6,
#    'address': 'calle de Luis Martinez Feduchi',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'Encinar de los Reyes',
#    'country': 'es',
#    'latitude': 40.5001316,
#    'longitude': -3.638256,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106006394/',
#    'description': 'Gilmar Consulting Inmobiliario ofrece, espectacular piso totalmente actualizado de 312 metros, en una de las mejores urbanizaciones de El Encinar de los Reyes. Al acceder a esta exclusiva vivienda, destaca la majestuosidad de su salón- comedor, con acceso a una maravillosa terraza con vistas despejadas. Cuenta con cocina independiente, con mobiliario y electrodomésticos de primera calidad, moderna y actual; amplio office con vistas; así como tendedero techado con área de lavandería. Un aseo de cortesía completa esta estancia; así como múltiples armarios en los halls.  En el área de descanso, se distribuyen tres (en origen cuatro) fantásticos dormitorios en suite; el principal con dos baños (para él y ella), así como una preciosa terraza con vistas. Adicionalmente hay una habitación que puede funcionar de servicio o como despacho. Esta espléndida y única propiedad dispone de tres plazas de garaje, un trastero, gimnasio y una preciosa piscina. La Moraleja, compuesta por La Moraleja, El Soto y El Encinar de los Reyes, es el área residencial de lujo por excelencia de Madrid y la más conocida de España, situada en la zona Norte de Madrid. Según algunas publicaciones de prestigio mundial, es la mejor urbanización del mundo, teniendo en cuenta sus cualidades. Está situada a 15 minutos del centro y a 5 minutos de la terminal Internacional 4 del Aeropuerto Adolfo Suárez. en el término municipal de Alcobendas. La Moraleja cuenta con el mayor número de colegios privados nacionales e internacionales de toda España (entre otros el International College Spain, King’s College, San Patricio, Runnymede, Los Sauces, Brains, Santa Helena, Saint George, Highlands, Aldovea, Liceo Europeo, etc…). Acoge además uno de los dos campus que la Universidad Europea de Madrid tiene en la Comunidad de Madrid. Cuenta asimismo con varios centros comerciales y médicos, dos campos de golf de 18 hoyos, club de tenis, club de pádel, y una de las ofertas gastronómicas más atractivas de Madrid. Hay que destacar La Plaza de la Moraleja, donde se encuentran los principales y más prestigiosos restaurantes de Madrid (A’Kangas, La Máquina, Áurea, La Penela, Mati´s Bar, Sushi 99) Cafeterías (Pino), Embassy, farmacia, bancos etc… Es un área que goza de gran seguridad gracias al sistema de alarmas que está conectado con la Entidad de Conservación de La Moraleja y las garitas de seguridad ubicadas en las diferentes entradas de acceso a la zona. Vivir en la Moraleja significa calidad, exclusividad y comodidad en un entorno inigualable y con los mejores servicios.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 5929.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Encinar de los Reyes, La Moraleja',
#     'title': 'Piso en calle de Luis Martinez Feduchi'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108324155',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/ca/0a/25/1344500754.webp',
#    'externalReference': 'AG210112',
#    'numPhotos': 41,
#    'floor': '4',
#    'price': 895000.0,
#    'priceInfo': {'price': {'amount': 895000.0, 'currencySuffix': '€'}},
#    'propertyType': 'penthouse',
#    'operation': 'sale',
#    'size': 106.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'calle de las Aguas',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Centro',
#    'country': 'es',
#    'neighborhood': 'Palacio',
#    'latitude': 40.4120656,
#    'longitude': -3.7117231,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108324155/',
#    'description': '**Exclusivo ático en el emblemático barrio de Palacio, Madrid**  Descubre este magnífico ático de 98m2 en uno de los enclaves más históricos y codiciados de Madrid. Este elegante inmueble cuenta con 2 dormitorios, 2 baños, una cocina completamente equipada y un salón independiente bañado por luz natural gracias a su orientación este. Su diseño exterior y su impecable estado de conservación lo convierten en un refugio perfecto para quienes buscan un hogar sofisticado y listo para entrar a vivir.  La finca, construida en 1940, es un ejemplo de arquitectura clásica madrileña y ha sido cuidadosamente mantenida para preservar su encanto original. Dispone de ascensor, calefacción individual de gas natural y aire acondicionado, proporcionando el máximo confort durante todo el año. El suelo de parquet y los acabados de alta calidad refuerzan la sensación de lujo y calidez.  Ubicado en pleno distrito Centro, a pocos pasos de lugares icónicos como el Palacio Real, la Plaza Mayor y la Catedral de la Almudena. Además, la zona ofrece una amplia oferta gastronómica, con tabernas tradicionales y restaurantes de alta cocina, así como teatros, galerías de arte y boutiques exclusivas.  El barrio también cuenta con una excelente conectividad. A menos de 500 metros se encuentran las estaciones de metro de Ópera (líneas 2, 5 y R) y La Latina (línea 5), además de varias líneas de autobús como la 31, 50 y 65. Para quienes prefieren el tren de cercanías, la estación de Príncipe Pío está a solo 1,5 kilómetros. A nivel educativo, el prestigioso Colegio San Ildefonso está a menos de 2 kilómetros, y en cuanto a compras, el Centro Comercial Príncipe Pío ofrece una amplia variedad de tiendas y servicios.  Desde 1983, en GILMAR nos hemos dedicado a ayudar a nuestros clientes a encontrar la casa de sus sueños, ofreciendo un servicio integral y personalizado. Somos referentes en el sector inmobiliario gracias a nuestra experiencia, profesionalidad y compromiso.  Para más información sobre este exclusivo ático, no dudes en contactar con nuestro equipo de la oficina de Centro. Estamos situados en Plaza de Herradores, 4, y puedes llamarnos al ** ** o escribirnos a ****. Por favor, facilita la referencia **210112** para que podamos atenderte de manera más eficiente. ¡Tu nuevo hogar te espera!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 8443.0,
#    'change': {},
#    'detailedType': {'typology': 'flat', 'subTypology': 'penthouse'},
#    'suggestedTexts': {'subtitle': 'Palacio, Madrid',
#     'title': 'Ático en calle de las Aguas'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108046286',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/79/1d/ca/1332214225.webp',
#    'externalReference': 'SG207844',
#    'numPhotos': 32,
#    'floor': '2',
#    'price': 970000.0,
#    'priceInfo': {'price': {'amount': 970000.0,
#      'currencySuffix': '€',
#      'priceDropInfo': {'formerPrice': 995000.0,
#       'priceDropValue': 25000,
#       'priceDropPercentage': 3}}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 169.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'calle de Vallehermoso',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Chamberí',
#    'country': 'es',
#    'neighborhood': 'Arapiles',
#    'latitude': 40.4388426,
#    'longitude': -3.7073215,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108046286/',
#    'description': 'En el prestigioso barrio de Vallehermoso, dentro del distrito de Chamberí, se encuentra un piso excepcional que redefine el concepto de vida urbana. Con una superficie de 169 m², esta vivienda en altura ofrece un ambiente de luminosidad y confort inigualable, gracias a su orientación suroeste que garantiza la entrada de luz natural durante todo el día. El inmueble cuenta con tres amplios dormitorios y dos baños, ideales para familias que buscan espacio y comodidad. El salón independiente proporciona un área de estar perfecta para el descanso y el entretenimiento, mientras que la cocina equipada es un espacio funcional para los amantes de la gastronomía. El piso está diseñado para el máximo confort, con calefacción central con contador individual y aire acondicionado, asegurando una temperatura ideal durante todo el año. Además, dispone de una plaza de garaje, un lujo que pocos pueden ofrecer en esta zona. La seguridad y el servicio son prioritarios, con un portero conserje que garantiza tranquilidad a los residentes. Ubicado en un edificio con ascensor, el estado de conservación del inmueble es para entrar a vivir o reformar. El piso también incluye un tendedero, lo que añade funcionalidad al día a día. Plaza de garaje no incluida en el precio a tan solo seis minutos andando de la vivienda, 39.000€. Vallehermoso es una zona que combina a la perfección la tranquilidad residencial con la vibrante vida urbana. A menos de 10 kilómetros, se encuentra el Colegio Santa María del Pilar, reconocido por su excelencia académica. Para las compras y el ocio, el Centro Comercial Moda Shopping es una opción cercana y completa. En cuanto a transporte público, las líneas de metro más cercanas son Islas Filipinas (Línea 7) y Moncloa (Líneas 3 y 6), y las líneas de autobuses que pasan por la zona incluyen el 16 y el 61, entre otras, facilitando el acceso a cualquier punto de la ciudad. Desde 1983, GILMAR se ha dedicado a ayudar a sus clientes a encontrar la casa de sus sueños, ofreciendo un servicio personalizado y de calidad. Con una trayectoria impecable, GILMAR se ha consolidado como líder en el sector inmobiliario, combinando experiencia y dedicación para satisfacer las necesidades de cada cliente. Para más información sobre este inmueble, por favor, contacta con nuestro equipo de Chamberí - Argüelles en C/ Carranza, 20, llamando al o escribiendo a. No olvides mencionar la referencia 207844 para que podamos asistirte de manera más eficiente.',
#    'hasVideo': True,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 39000.0},
#    'priceByArea': 5740.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Arapiles, Madrid',
#     'title': 'Piso en calle de Vallehermoso'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '105036254',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/58/39/8c/1302328500.webp',
#    'externalReference': 'GH196907',
#    'numPhotos': 48,
#    'floor': '2',
#    'price': 1495000.0,
#    'priceInfo': {'price': {'amount': 1495000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 164.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'calle de Noblejas',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Centro',
#    'country': 'es',
#    'neighborhood': 'Palacio',
#    'latitude': 40.4153152,
#    'longitude': -3.7138457,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/105036254/',
#    'description': '¡Exclusivo Piso en Venta en el Corazón de Madrid! Este impresionante piso de 164 m² combina elegancia, confort y una ubicación inmejorable, ideal para quienes buscan vivir en una vivienda de alta calidad y con historia. Además, ha sido completamente reformado y está listo para estrenar, con acabados y mobiliario totalmente nuevos que garantizan calidad, funcionalidad y un estilo impecable. Alojado en un magnífico edificio en el corazón de Madrid, construido en 1834 y con casi dos siglos de historia, este inmueble aporta un carácter y un valor patrimonial únicos a la propiedad. El apartamento ha sido reformado con las más altas calidades, asegurando durabilidad y un acabado personalizado perfecto. La reforma incluye detalles de lujo como persianas eléctricas que ofrecen ventajas como mayor comodidad, seguridad, eficiencia energética y un valor estético y funcional añadido. El luminoso salón, corazón de la vivienda, cuenta con tres encantadores balcones que permiten la entrada de abundante luz natural y ofrecen vistas privilegiadas de la zona. La cocina abierta con península, equipada con electrodomésticos de última generación y acabados de alta calidad, es perfecta para los amantes de la gastronomía y las reuniones con amigos y familiares. El piso dispone de tres habitaciones espaciosas, incluyendo una habitación principal con baño en suite, creando un oasis privado para descansar y relajarse. Las otras dos habitaciones son versátiles, ideales para dormitorios adicionales, una oficina en casa o espacios para invitados. Todas ellas comparten un baño completo moderno y funcional, además de un aseo de cortesía elegante y práctico para mayor comodidad. El confort está garantizado con suelo de piedra de Campaspero, que ofrece excelentes ventajas para su uso en suelos radiantes: buena conductividad térmica, capacidad de retención de calor, durabilidad, estética atractiva y facilidad de mantenimiento. La calefacción por suelo radiante y el aire acondicionado por conductos aseguran una temperatura agradable durante todo el año. Las puertas interiores en altura, hechas a medida, aportan un ambiente amplio y lujoso, mejoran la circulación del aire y la accesibilidad, además de potenciar la estética del espacio. Las luces dimables permiten crear ambientes personalizados, contribuyendo a la sostenibilidad ambiental y al bienestar del hogar. El inmueble también cuenta con una chimenea que aporta calidez, confort y un toque de elegancia, transformando cualquier espacio en un lugar más acogedor y funcional. Vive en una ubicación exclusiva, con fácil acceso a sitios históricos, parques, tiendas y restaurantes. Además, la finca está exenta de pagar IBI por ser un edificio protegido, lo que representa un ahorro significativo en gastos anuales. ¡No pierdas la oportunidad de vivir en uno de los barrios más emblemáticos de Madrid!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 9116.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Palacio, Madrid',
#     'title': 'Piso en calle de Noblejas'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106751275',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/57/2a/4b/1319043313.webp',
#    'externalReference': 'PV8826I',
#    'numPhotos': 82,
#    'price': 9000000.0,
#    'priceInfo': {'price': {'amount': 9000000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 1674.0,
#    'rooms': 9,
#    'bathrooms': 10,
#    'address': 'calle Eibar',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Moncloa',
#    'country': 'es',
#    'neighborhood': 'El Plantío',
#    'latitude': 40.469054,
#    'longitude': -3.8103585,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106751275/',
# ...
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 6167.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Bernabéu-Hispanoamérica, Madrid',
#     'title': 'Casa independiente en avenida del Levante'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108008597',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/05/27/21/1339267256.webp',
#    'externalReference': 'MAV02793',
#    'numPhotos': 43,
#    'floor': '3',
#    'price': 1200000.0,
#    'priceInfo': {'price': {'amount': 1200000.0,
#      'currencySuffix': '€',
#      'priceDropInfo': {'formerPrice': 1250000.0,
#       'priceDropValue': 50000,
#       'priceDropPercentage': 4}}},
#    'propertyType': 'penthouse',
#    'operation': 'sale',
#    'size': 220.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'Barrio Virgen del Cortijo - Manoteras',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Hortaleza',
#    'country': 'es',
#    'neighborhood': 'Virgen del Cortijo - Manoteras',
#    'latitude': 40.485068,
#    'longitude': -3.668286,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108008597/',
#    'description': 'De SALAS LUXURY HOMES Ref. MAV02793, les presenta este exclusivo ático tríplex con piscina privada en Isla de Chamartín. MUCHAS DE NUESTRAS PROPIEDADES NO APARECEN EN IDEALISTA. CONSULTE EN NUESTRA PÁGINA WEB DE “De Salas”, PARA VER MÁS VIVIENDAS EN EXCLUSIVA. Con una superficie de 218 m² catastrales, cuenta con un diseño único y funcional, disfrutando de una terraza de 50m² con piscina privada e impresionantes vistas panorámicas. Goza de una gran privacidad, siendo la luz su principal protagonista. Distribuida en 3 plantas, permite disfrutar de amplios espacios perfectamente diferenciados. Accedemos a la planta principal, a través de un hall de entrada con armario gabanero, que da paso a un amplio salón, abierto al exterior a través de grandes ventanales, que aportan una gran luminosidad. La cocina, de diseño moderno y funcional, se encuentra totalmente amueblada y equipada con electrodomésticos de alta gama. Dispone de un práctico cuarto de lavandería independiente. Una coqueta terraza con doble acceso directo desde la cocina y desde el salón, convierte este espacio en uno de los rincones preferidos de la vivienda. Un aseo de cortesía da servicio a la planta. En planta baja se ubica la zona de descanso. Un amplio hall con espacio para utilizarlo como despacho, nos da acceso a dos amplios dormitorios con armarios empotrados y que comparten un baño completo con ventana exterior. El dormitorio principal de destacadas dimensiones, dispone de baño en suite, con plato de ducha y bañera de hidromasaje, y cuenta con armarios de gran capacidad de almacenaje. En la planta superior encontramos una espectacular terraza solarium, con piscina privada, donde relajarse y disfrutar de grandes celebraciones con familiares y amigos, en un entorno privilegiado e inmejorable. Construido con las mejores calidades, la vivienda cuenta con sistema de calefacción mediante suelo radiante, aire acondicionado por conductos, sectorizado por plantas, persianas motorizadas, sistema de domótica, etc. La vivienda cuenta con 2 amplias plazas de garaje con acceso directo y un trastero, aportando ese espacio extra tan práctico y necesario. Ubicada en una de las urbanizaciones más exclusivas y representativas de Isla de Chamartín, cuenta con servicio de conserjería y vigilancia 24 horas, piscina comunitaria, sauna, un atractivo gimnasio abierto al exterior con toda la maquinaría propia de un club privado y área infantil. Isla de Chamartín debido a su ubicación se ha convertido en una zona privilegiada, cerca del área financiera y empresarial de la capital, próximo al aeropuerto de Barajas y al recito ferial IFEMA. Perfectamente comunicado, con rápido acceso desde M-30, M-40 y A-1, dispone de buena conexión mediante transporte público, con la estación de cercanías y metro ligero de Fuente de la Mora, y numerosas líneas de autobús.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 5455.0,
#    'change': {},
#    'detailedType': {'typology': 'flat', 'subTypology': 'penthouse'},
#    'suggestedTexts': {'subtitle': 'Virgen del Cortijo - Manoteras, Madrid',
#     'title': 'Ático'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108552407',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/23/c2/70/1348241483.webp',
#    'externalReference': 'W-0306LR',
#    'numPhotos': 68,
#    'price': 1400000.0,
#    'priceInfo': {'price': {'amount': 1400000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 539.0,
#    'rooms': 6,
#    'bathrooms': 3,
#    'address': 'calle Nuestra Señora de Nuria',
#    'province': 'Madrid',
#    'municipality': 'Pozuelo de Alarcón',
#    'district': 'Zona Estación',
#    'country': 'es',
#    'neighborhood': 'Zona Estación',
#    'latitude': 40.4404198,
#    'longitude': -3.7987573,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108552407/',
#    'description': 'Interesante unifamiliar en Pozuelo con múltiples posibilidades. Engel & Völkers ofrece una magnífica propiedad unifamiliar, ubicada en una zona residencial de Pozuelo. Se trata de una casa de dos plantas más semisótano diáfano, con 180m2 cada nivel, y con entradas independientes desde el jardín. Lo que permite su uso como viviendas autónomas o su transformación en una única residencia familiar de gran amplitud. Su estética de estilo mid-century confiere a toda la propiedad su carácter especial y su valor más atractivo. La planta principal se utiliza actualmente como "casa de invierno". En este nivel se encuentra el núcleo más tradicional del hogar: un amplio salón con grandes ventanales a la terraza; la cocina funcional y espaciosa; cuatro dormitorios y dos baños completos. Una bonita escalera interior de madera la comunica con la "casa de verano" de la planta cero, a nivel del jardín. La generosa terraza aporta no sólo la entrada abundante de luz natural, sino también una orientación ideal para disfrutar del sol de invierno, y la personalidad mid-century de toda la propiedad. Esta casa de invierno tiene su propio acceso al jardín desde la terraza a través de una escalera de piedra, también con marcado estilo cincuenta. La segunda planta fue pensada como refugio ideal para los meses más cálidos de Madrid. Diseñada como vivienda independiente, ofrece un gran salón protegido del sol del verano por el porche exterior creado por la terraza de la planta principal. Zona que ofrece un espacio magnífico para disfrutar del jardín en las noches de verano. Por supuesto, cuenta con cocina con una amplia despensa que puede integrarse, para crear un espacio moderno y funcional. El dormitorio principal cuenta con baño en suite, y una habitación adicional que puede reconvertirse en gran vestidor. Además cuenta con otro amplio dormitorio conectado con el salón. Esta planta tiene acceso directo al garaje donde se ubica un moderno ascensor. El sótano ofrece un espacio diáfano perfecto para uso profesional, estudio artístico o taller de hobbies como cerámica, escultura, o costura. Su acceso directo al jardín la hacen ideal para una actividad de clientes o visitas externas, con entrada totalmente independiente. Extras y potencial La propiedad cuenta con un ascensor moderno recién instalado, que conecta desde el amplio garaje (capacidad para tres vehículos) hasta las dos plantas principales. El jardín privado cuenta con una amplia piscina y una zona deportiva, en una parcela que ofrece privacidad y tranquilidad. La distribución actual permite múltiples posibilidades: Convertirla en una única vivienda familiar con zonas diferenciadas. Reformar y mantener su estructura actual para alquilar por plantas. Atraer el interés de promotores e inversores para realizar una obra nueva con posibilidad de construir un pareado; o un bajo con jardín, y un piso con espectacular terraza para alquiler. Una propiedad singular, con encanto, funcionalidad y alto potencial de rentabilidad. Una oportunidad única en Pozuelo para vivir, invertir o desarrollar. Pozuelo de Alarcón es una localidad en el Noroeste de la Comunidad de Madrid. Su enclave privilegiado por su proximidad a la capital, sus amplias zonas verdes y jardines, y sus servicios de calidad (Colegios y Universidades, Hoteles, Centros Comerciales de lujo, Hospitales privados de reconocido prestigio) han hecho que sea elegida como lugar de residencia por sectores de gran nivel adquisitivo, profesional y cultural de la sociedad madrileña. Posee excelentes comunicaciones con el centro y sus alrededores a través de: autovías y carreteras (M-30, M-40, M-503 y A-6); estaciones de Cercanías (Pozuelo y El Barrial, líneas C-7 y C-10); y líneas de autobuses urbanos e interurbanos (560, 561, 561A, 561B, 5 56A, y los nocturnos N901, N902, N905 y N906). Sin olvidar las líneas especiales A y H que enlazan al campus.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 2597.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Zona Estación, Pozuelo de Alarcón',
#     'title': 'Casa independiente en calle Nuestra Señora de Nuria'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '107526421',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/65/eb/31/1315425480.webp',
#    'externalReference': 'GH202391',
#    'numPhotos': 44,
#    'floor': '3',
#    'price': 920000.0,
#    'priceInfo': {'price': {'amount': 920000.0,
#      'currencySuffix': '€',
#      'priceDropInfo': {'formerPrice': 980000.0,
#       'priceDropValue': 60000,
#       'priceDropPercentage': 6}}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 146.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'calle de las Fuentes',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Centro',
#    'country': 'es',
#    'neighborhood': 'Sol',
#    'latitude': 40.4167924,
#    'longitude': -3.7074916,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/107526421/',
#    'description': 'GILMAR Consulting Inmobiliario presenta, en exclusiva, elegante vivienda en el barrio de Palacio. Con una superficie construida de 146 m2, dispone de 3 dormitorios y 2 cuartos de baños completos, además de amplio vestidor en el dormitorio principal. Situada en una ubicación privilegiada, la vivienda se encuentra rodeada de todo tipo de comodidades y servicios en la zona. El inmueble destaca por su luminosidad gracias a su orientación sureste, lo que permite disfrutar de una gran cantidad de luz natural durante todo el día. Además, cuenta con cuatro balcones a la calle con impresionantes vistas al centro de la ciudad. La vivienda ha sido completamente reformada con materiales de primera calidad: los suelos de parquet y la carpintería interior de madera natural aportan un toque de elegancia y calidez. La cocina, con una isla central y electrodomésticos integrados, es el lugar perfecto para los amantes de la cocina. Además, el centro comercial más cercano es Plaza de Isabel Segunda, donde se pueden encontrar una gran variedad de tiendas, restaurantes y servicios de ocio. También hay varias líneas de metro cercanas, como la estación de Metro Ópera, a solo 1 minuto a pie, que conecta con el resto de la ciudad de manera rápida y eficiente. El barrio de Palacio es conocido por su historia y encanto. Está situado junto al Palacio Real y la Plaza de Oriente, lo que lo convierte en un lugar ideal para aquellos que buscan vivir en un entorno lleno de cultura y tradición. Además, cuenta con una amplia oferta de restaurantes, bares y tiendas exclusivas que hacen de esta zona un lugar vibrante y lleno de vida. En cuanto al transporte público, las líneas de autobús más cercanas a la ubicación del inmueble son la línea 3 y la línea 148, que ofrecen conexiones a diferentes partes de la ciudad. GILMAR es una reconocida compañía inmobiliaria con una amplia experiencia en el sector. Desde 1983, hemos estado ayudando a nuestros clientes a encontrar la casa de sus sueños. Nuestro equipo de expertos en marketing inmobiliario se dedica a ofrecer descripciones detalladas y atractivas de cada propiedad, destacando sus características únicas y su ubicación privilegiada. Si estás interesado en obtener más información sobre este impresionante piso en Palacio, por favor, no dudes en contactarnos y facilitarnos la referencia del inmueble. Nuestro equipo estará encantado de ayudarte y proporcionarte todos los detalles que necesites para tomar la mejor decisión. Puedes visitarnos en nuestra oficina en Plaza de Herradores, 4 o llamarnos al ¡Esperamos poder ayudarte a encontrar tu nuevo hogar!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 6301.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Sol, Madrid',
#     'title': 'Piso en calle de las Fuentes'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True}],
#  'total': 22545,
#  'totalPages': 451,
#  'actualPage': 1,
#  'itemsPerPage': 50,
#  'numPaginations': 0,
#  'summary': ['Comprar',
#   'Casas y pisos',
#   'Madrid provincia',
#   'Todos los precios',
#   'Todos los tamaños'],
#  'filter': {'locationName': 'Madrid'},
#  'alertName': 'Viviendas en Madrid',
#  'totalAppliedFilters': 0,
#  'lowerRangePosition': 0,
#  'paginable': True,
#  'upperRangePosition': 50}

# %%
token, expires = idealista_token(api_key, secret)

response = query(token, filter_request)

# %%
response
# Out:
# {'elementList': [{'propertyCode': '107203987',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/95/ed/45/1311342091.webp',
#    'externalReference': 'V7159I',
#    'numPhotos': 31,
#    'floor': '3',
#    'price': 1550000.0,
#    'priceInfo': {'price': {'amount': 1550000.0, 'currencySuffix': '€'}},
#    'propertyType': 'penthouse',
#    'operation': 'sale',
#    'size': 158.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'camino de los Jardines, 7',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'La Moraleja urbanización',
#    'country': 'es',
#    'latitude': 40.5071718,
#    'longitude': -3.6087171,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/107203987/',
#    'description': 'Venta. Piso. La Moraleja. Promora ofrece excepcional piso a estrenar en la prestigiosa comunidad “ The Garden La Moraleja “, la urbanización se distingue por sus instalaciones de lujo diseñadas para el disfrute y el bienestar de sus residentes, amplias piscina con iluminación nocturna, rodeadas de jardines, espacio con sofás rodeados de vegetación, spa y sauna. Tres dormitorios con dos baños y aseo.   La distribución es la siguiente: hall de entrada, salón y cocina abierta con tendedero y aseo. Tiene 3 dormitorios con 2 baños, el dormitorio principal con baño incorporado en suite.  Aire acondicionado. Calefacción por aerotermia.  Dos plazas de garaje.  Trastero.  Excelente urbanización con dos piscinas, sauna, spa y zonas deportivas.  Probablemente La Moraleja sea la urbanización residencial de lujo más conocida de España. Los muchos personajes famosos que la han elegido como residencia habitual son responsables de su importante presencia mediática. Situada al norte de Madrid, en el término municipal de Alcobendas, tiene una extensión de 950 hectáreas. Cuenta con 1050 viviendas independientes sobre parcelas de 1.500, 2.500 y 10.000 m2 y con 400 adosados en 9 urbanizaciones diferentes. Tanto su estratégica ubicación -a un paso del centro de la capital (12km) y a escasos kilómetros del aeropuerto de Barajas (5km)- como sus férreas medidas de seguridad y sus muchas opciones de escolarización privada, ocio, deporte y salud, han convertido La Moraleja en un referente residencial en nuestro país.  Junto a las urbanizaciones de El Soto y El Encinar, conforman un núcleo geográfico de similares características demográficas. Su código postal es el 28109. Es aquí, en la plaza de La Moraleja (junto a la farmacia), donde Promora atiende a los clientes que quieren acceder a las viviendas de la zona norte de Madrid. Puedes ver más inmuebles en nuestra página web.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 9810.0,
#    'change': {},
#    'detailedType': {'typology': 'flat', 'subTypology': 'penthouse'},
#    'suggestedTexts': {'subtitle': 'La Moraleja urbanización, La Moraleja',
#     'title': 'Ático en camino de los Jardines, 7'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108816285',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/a7/b1/9e/1356236609.webp',
#    'externalReference': 'VG-212295',
#    'numPhotos': 32,
#    'floor': 'bj',
#    'price': 1250000.0,
#    'priceInfo': {'price': {'amount': 1250000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 166.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'paseo de los Parques',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'Encinar de los Reyes',
#    'country': 'es',
#    'latitude': 40.5111465,
#    'longitude': -3.6527442,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108816285/',
#    'description': 'Gilmar Consulting Inmobiliario, ofrece en exclusiva, luminoso y espacioso piso de tres dormitorios y amplia terraza con gran jardín en una de las mejores urbanizaciones de El Encinar de los Reyes. Tiene una ubicación inigualable a pasos de La Plaza de la Moraleja y del Centro Comercial El Encinar. Se encuentra dentro de una urbanización privada, con los mejores servicios como piscina exterior para adultos y niños, pádel, zonas comunes de paseo y seguridad física 24h con estricto control de acceso. Iniciando su recorrido, nos da la bienvenida un luminoso salón-comedor con acceso a la terraza exterior y a un jardín de 136 metros. Cuenta con cocina independiente, con mobiliario y electrodomésticos; así como tendedero techado con área de lavandería. En el área de descanso, se distribuyen dos fantásticos dormitorios con armarios empotrados y dos baños completos; el de la habitación principal en suite.  El piso cuenta con un apartamento independiente con acceso desde la cocina. Consta de un dormitorio con baño en suite, gran trastero y acceso a las dos plazas de garaje. La Moraleja, compuesta por La Moraleja, El Soto y El Encinar de los Reyes, es el área residencial de lujo por excelencia de Madrid y la más conocida de España, situada en la zona Norte de Madrid. Según algunas publicaciones de prestigio, es la mejor urbanización del mundo, teniendo en cuenta sus cualidades.  Está situada a 15 minutos del centro de Madrid y a 10 minutos de la Terminal Internacional 4 del Aeropuerto Adolfo Suárez.  La Moraleja cuenta con el mayor número de colegios privados nacionales e internacionales de toda España (entre otros el International College Spain, King’s College, San Patricio, Runnymede, Los Sauces, Brains, Santa Helena, Saint George, Highlands, Aldovea, Liceo Europeo, etc…) Acoge además uno de los dos campus que la Universidad Europea de Madrid tiene en la Comunidad de Madrid.  La zona tiene gran cercanía al Parque Forestal de Valdebebas, el segundo más grande de Madrid), varios centros comerciales, supermercados, hospitales, centros médicos, dos campos de golf de 18 hoyos, club de tenis, club de pádel, y una de las ofertas gastronómicas más atractivas de Madrid.  Hay que destacar La Plaza de la Moraleja, donde se encuentran los principales y más prestigiosos restaurantes de Madrid (A’Kangas, Áurea, La Máquina, La Penela, El Barril, Sushi 99, Peppe Fusco) Cafeterías (Café Pino, Panod), farmacias, panaderías, bancos etc… Es un área que goza de gran seguridad gracias al sistema de alarmas que está conectado con la Entidad de Conservación de La Moraleja y las garitas de seguridad ubicadas en las diferentes entradas de acceso a la zona. ¡Vivir en la Moraleja significa calidad, exclusividad y comodidad en un entorno inigualable!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 7530.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Encinar de los Reyes, La Moraleja',
#     'title': 'Piso en paseo de los Parques'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106702840',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/2d/e6/4f/1297219632.webp',
#    'externalReference': 'PV8891I',
#    'numPhotos': 51,
#    'floor': '2',
#    'price': 1335000.0,
#    'priceInfo': {'price': {'amount': 1335000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 157.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'calle del Carril de los Caleros',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Moncloa',
#    'country': 'es',
#    'neighborhood': 'Aravaca',
#    'latitude': 40.4602576,
#    'longitude': -3.7968684,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106702840/',
#    'description': 'Impecable piso de 157 m² con terraza de 130 m² en venta en urbanización cerrada con piscina. En buenísima ubicación por cercanía a zona comercial y de ocio, servicios y bien comunicada por transporte público y principales carreteras. Distribución: · Amplio hall de recibo. · Aseo de visitas. · Armario gabanero. · Cocina office con tendedero y salida a terraza. · Salón comedor con salida a terraza. · Dos dormitorios. · Baño completo. · Dormitorio principal con vestidor y baño completo. Puedes ver más inmuebles en nuestra página web. Entre el Monte del Pardo y la Casa de Campo, y a tan solo 9 kilómetros del centro de Madrid, Aravaca es un lugar privilegiado: ofrece todo lo que un ciudadano necesita en una gran urbe, y además está perfectamente comunicada con la capital gracias a la autopista A-6, la M-500, la M-503 (carretera de Castilla), M-30 y M-40. Cuenta con múltiples instalaciones deportivas, tiendas, restaurantes, academias, institutos, así como con los colegios más prestigiosos de Madrid. Es un área con mucho encanto donde sus 23.000 habitantes disfrutan de las ventajas de vivir en una gran ciudad, y a su vez de la tranquilidad de estar en un pueblo donde pasear, ir de compras caminando, e incluso ir en bici hasta el centro de Madrid o Ciudad Universitaria a través de la Casa de Campo.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 8503.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Aravaca, Madrid',
#     'title': 'Piso en calle del Carril de los Caleros'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106349275',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/a3/c1/5a/1281719993.webp',
#    'externalReference': 'PV8839I',
#    'numPhotos': 66,
#    'price': 2975000.0,
#    'priceInfo': {'price': {'amount': 2975000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 818.0,
#    'rooms': 6,
#    'bathrooms': 6,
#    'address': 'calle Transversal 1',
#    'province': 'Madrid',
#    'municipality': 'Pozuelo de Alarcón',
#    'district': 'Urbanizaciones',
#    'country': 'es',
#    'neighborhood': 'Montealina',
#    'latitude': 40.4227208,
#    'longitude': -3.8426658,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106349275/',
#    'description': 'Fantástico chalet independiente de 818 m² en fantástica parcela de esquina de 3.603 m² diseñada con grandes espacios comunicados y abiertos al jardín. Con fantástica parcela con piscina, zona de barbacoa, horno de piedra y bonito jardín consolidado.  Distribución: PLANTA PRINCIPAL: - Hall de entrada. - Despacho con salida al jardín. - Amplio salón con salida al jardín  - Comedor con salida al jardín. - Cocina de gran tamaño, totalmente reformada, con zona de office. - Zona de lavado. - Apartamento de servicio con baño y acceso independiente. - Aseo de invitados. - Armario ropero. PRIMERA PLANTA: - Dormitorio principal en suite de gran tamaño con baño y vestidor. - Dormitorio con baño en suite. - Dos amplias habitaciones dobles de buen tamaño. - Baño completo. - Dormitorio con baño con suite. PLANTA BAJA:  - Salón con billar. - Despensa. - Zona de maquinas. - Trastero. - Bodega. - Garaje con capacidad para tres coches. Puedes ver más inmuebles en nuestra página web. Urbanización de lujo muy consolidada, de acceso cerrado y vigilancia las 24 horas. Pertenece al municipio de Pozuelo de Alarcón y ofrece un maravilloso paisaje donde se encuentra el bosque protegido de Boadilla del Monte.  Conectada por la M-40 y la M-500, tiene transporte público, y un fácil acceso a la zona comercial de Pozuelo. Como rasgo distintivo, todas las viviendas son chalets independientes en muy buenas parcelas de gran privacidad.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 3637.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Montealina, Pozuelo de Alarcón',
#     'title': 'Casa independiente en calle Transversal 1'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106010517',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/4e/70/35/1351929883.webp',
#    'externalReference': 'PV8838I',
#    'numPhotos': 46,
#    'price': 3950000.0,
#    'priceInfo': {'price': {'amount': 3950000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 1900.0,
#    'rooms': 7,
#    'bathrooms': 10,
#    'address': 'calle Línea',
#    'province': 'Madrid',
#    'municipality': 'Pozuelo de Alarcón',
#    'district': 'Zona Pueblo',
#    'country': 'es',
#    'neighborhood': 'Zona Pueblo',
#    'latitude': 40.4462524,
#    'longitude': -3.8173481,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106010517/',
#    'description': 'Chalet independiente de 1.900 m² con parcela de 5.900 m² en Pozuelo. Distribución: PLANTA BAJA: - Hall de acceso, dos aseos de cortesía. - Distribuidor central con piscina interior climatizada con fuente y jacuzi. - Salón con bar inglés. - Comedor. - Cocina y zonas de servicio (dormitorio con baño y zona de plancha). - Cuatro dormitorios tipo suite, con vestidor completo y baño integrado en la disposición de la habitación, con bañera y ducha independiente.  - Zona de gimnasio, comunicada con la habitación principal, con vestuarios, duchas, sauna, baño turco y sala de aparatos. PLANTA PRIMERA:  - Un dormitorio tipo suite, con vestidor completo y baño integrado en la disposición de la habitación, con bañera y ducha independiente, con terraza privada y estancias diáfanas de biblioteca y zona de pintura.  - Aseo de cortesía.  - Doble altura en sobre hall y salón, iluminados por cúpula cenital.  - Terrazas accesibles (preparadas para posibles ampliaciones, tanto estructuralmente como con preinstalación de todo tipo de instalaciones (agua, luz, telefonía, etc)). PLANTA SÓTANO: - Sala polivalente con barra de bar, bolera profesional y galería de tiro con arco (preparado como bunker, con todas las acometidas).  - Dormitorio de servicio y baño completo. - Taller de reparaciones y laboratorio fotográfico y cuartos varios de instalaciones. PLANTA TÉCNICA:  - Bajo la totalidad de la planta baja, cámara practicable de entre uno y dos metros de altura donde se alojan las instalaciones generales incluidas las de la piscina interior, hasta un total de 800 m². Todas las plantas están comunicadas entre si por escalera y ascensor. Aparcamiento cubierto en planta baja, junto a la entrada con capacidad para ocho vehículos. Jardín arbolado, con piscina, terraza exterior, barbacoa y caseta para perros.  Puedes ver más inmuebles en nuestra página web. Este importante municipio de Madrid ocupa una extensión de 42 km2 y tiene una población de aproximadamente 84.000 habitantes. Como referencia geográfica, se encuentra a 11 kilómetros del centro de la capital y linda con Aravaca. Además de varias líneas de autobuses y de metro ligero, cuenta con dos estaciones de cercanías: una en Pozuelo y otra en El Barrial, junto al Corte Inglés. Sin olvidar sus tres grandes ejes: la A-6, la M-500 y la M-40.  De entres sus muchas urbanizaciones, destacamos La Finca, Somosaguas o Álamos de Bularas. Según su carácter urbanístico, en algunas se han construido pisos cerca de las zonas comerciales, y en otras, adosados y chalets independientes.  Asimismo, cuenta con colegios muy conocidos, algunos de ellos bilingües, lo que hace de esta población una zona muy demandada por ejecutivos destinados en Madrid. En sus inmediaciones se encuentra el Campus Universitario de Somosaguas, donde se cursan varias carreras de la Universidad Complutense.  Estamos ante una zona muy tranquila, de gran seguridad y con unos servicios acordes a la gran ciudad que es hoy día. De hecho, desde hace ya unos años tiene teatro y su propio conservatorio.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 2079.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Zona Pueblo, Pozuelo de Alarcón',
#     'title': 'Casa independiente en calle Línea'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '107999491',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/60/75/61/1352741728.webp',
#    'externalReference': 'PV9078I',
#    'numPhotos': 49,
#    'floor': 'bj',
#    'price': 2250000.0,
#    'priceInfo': {'price': {'amount': 2250000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 188.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 4,
#    'address': 'avenida de Luis García Cereceda',
#    'province': 'Madrid',
#    'municipality': 'Pozuelo de Alarcón',
#    'district': 'Zona Prado de Somosaguas - La Finca',
#    'country': 'es',
#    'neighborhood': 'La Finca',
#    'latitude': 40.406757,
#    'longitude': -3.7982987,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/107999491/',
#    'description': 'Exclusivo bajo con jardín de esquina, con piscina privada, en la exclusiva urbanización de La Finca LGC3. La vivienda está orientada al sur por lo que goza de una maravillosa luz. Vistas al recién inaugurado campo de golf de 18 hoyos, cuenta con 339 m² construidos, de los cuales 188 m² son de vivienda, y 137 m² de terraza y piscina privada. Disfruta de un jardín privado de 147 m² con acceso a las zonas comunes, y un agradable porche. En un enclave único, en una de las urbanizaciones más seguras de Europa, con un sistema férreo de seguridad, cerrada y vigilada 24 horas. En magnífica ubicación por su cercanía al centro comercial Grand Café de La Finca, y de colegios internacionales como el Colegio Británico o el Americano. Bien comunicada por transporte público y con fácil acceso con carreteras principales.  Distribución: · Amplio hall de recibo, baño completo y armario gabanero. · Salón comedor. · Cocina oficce con isla central semi-integrada a través de unas puertas correderas con cuarterones diseñada específicamente para esta vivienda. Ambas estancias tienen salida al porche y al jardín. · En la zona de dormitorios encontramos un amplio frente de armarios para ropa blanca y almacenaje. · Dormitorio con baño en suitte. · Dormitorio con baño en suitte. · Dormitorio principal con baño en suitte y vestidor. · Zona de lavado plancha independiente. · Dormitorio de servicio. Dos plazas de garaje y trastero. Puedes ver más inmuebles en nuestra página web. A La Finca se la conoce como la urbanización más segura de toda Europa. Es muy demandada, además, por su privacidad y el cuidado exquisito de sus zonas comunes. Como rasgo de estilo, posee maravillosos lagos y jardines, así como una arquitectura perfectamente estudiada y uniforme, que podemos ver en sus pisos, adosados, pareados y chalets independientes. Situada en el término municipal de Pozuelo de Alarcón, La Finca se halla muy bien comunicada por la M-40 y la carretera de Castilla. Tiene también varias líneas de autobuses, metro ligero y tren de cercanías.  Cuenta con un club deportivo, restaurantes y un centro comercial que cubre todas las necesidades de sus residentes. En sus inmediaciones encontramos algunos de los mejores colegios de Madrid y se halla a tan solo 5 minutos de Pozuelo.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 11968.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'La Finca, Pozuelo de Alarcón',
#     'title': 'Piso en avenida de Luis García Cereceda'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108212506',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/d7/21/4d/1337699789.webp',
#    'externalReference': 'LO-209361',
#    'numPhotos': 34,
#    'price': 1795000.0,
#    'priceInfo': {'price': {'amount': 1795000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 260.0,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'calle del Padre Arrupe',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'Encinar de los Reyes',
#    'country': 'es',
#    'latitude': 40.5027596,
#    'longitude': -3.6371706,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108212506/',
#    'description': 'Gilmar Moraleja Consulting te invita descubrir EN EXCLUSIVA esta espectacular casa pareada en una urbanización cerrada con seguridad 24 horas, ubicada en la exclusiva zona de El Encinar de los Reyes. Con un diseño funcional y acogedor, esta propiedad de 260 m² construidos se distribuye en dos plantas que ofrecen un ambiente perfecto para disfrutar en familia. En la planta baja, te recibe un hall de entrada que da paso a un amplio salón comedor, ideal para momentos inolvidables. La cocina, equipada con zona de office y acceso directo al jardín, es perfecta para los amantes de la gastronomía. Además, cuenta con un baño completo que añade comodidad a este nivel.  Subiendo a la planta primera, encontrarás dos generosos dormitorios secundarios, que pueden unirse para crear un espacio aún más amplio. La habitación principal destaca por su tamaño y cuenta con un baño en suite que garantiza privacidad y confort. Un baño secundario compartido completa esta planta. La propiedad también incluye plaza de garaje para dos vehículos y un gran trastero, ofreciendo soluciones de almacenamiento adicionales y instalación de fotovoltaica individual en cubierta con posibilidad de instalar acumuladores. Los servicios de la urbanización son excepcionales: disfruta de dos piscinas (adultos y niños), pistas de pádel y tenis, un parque infantil y amplias zonas ajardinadas donde los más pequeños pueden jugar y explorar. Esta casa está lista para convertirse en tu nuevo hogar. No pierdas la oportunidad de vivir en un entorno seguro y tranquilo, rodeado de naturaleza y comodidades. ¡Ven a visitarla y enamórate! La Moraleja es el área residencial de lujo por excelencia de Madrid y la más conocida de España. Se sitúa en la zona Norte de la capital y está compuesta por La Moraleja, El Soto de la Moraleja y El Encinar de los Reyes. Según algunas publicaciones de prestigio mundial, La Moraleja es la mejor urbanización del mundo, teniendo en cuenta sus cualidades: situada a 10 minutos del centro de Madrid y a 5 minutos de la Terminal Internacional 4 del Aeropuerto Adolfo Suárez Barajas, en el término municipal de Alcobendas. Tiene una extensión de 950 hectáreas, con 1.050 viviendas independientes sobre parcelas de 1.500, 2.500 y 10.000 m2 y con 400 chalets adosados en nueve urbanizaciones diferentes. La Moraleja cuenta con el mayor número de colegios privados nacionales e internacionales de toda España, entre otros, el International College, King’s College, San Patricio, Runymede, Los Sauces, Brains, Saint George, Highlands, Aldovea, Liceo Europeo…. Acoge además uno de los dos campus que la Universidad Europea de Madrid tiene en la Comunidad de Madrid. Cuenta asimismo con varios centros comerciales y médicos, dos campos de golf de 18 hoyos, club de tenis, club de paddle, y una de las ofertas gastronómicas más atractivas de Madrid. Hay que destacar La Plaza de la Moraleja, donde se encuentran los principales y más prestigiosos restaurantes de Madrid (A’Kangas, La Máquina, Aurea, La Penela, Sushi99), cafeterías como Pino, Embassy o farmacia y bancos. La Moraleja es un área que goza de gran seguridad gracias al sistema de alarmas que está conectado con la Entidad de Conservación de La Moraleja y las garitas de seguridad ubicadas en las diferentes entradas de acceso a la zona. Vivir en la Moraleja significa calidad, exclusividad y comodidad en un entorno inigualable y con los mejores servicios.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 6904.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'semidetachedHouse'},
#    'suggestedTexts': {'subtitle': 'Encinar de los Reyes, La Moraleja',
#     'title': 'Chalet pareado en calle del Padre Arrupe'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '104306965',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/aa/c2/63/1217034679.webp',
#    'externalReference': 'JM195047 ',
#    'numPhotos': 53,
#    'price': 15000000.0,
#    'priceInfo': {'price': {'amount': 15000000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 1700.0,
#    'rooms': 8,
#    'bathrooms': 11,
#    'address': 'paseo de la Marquesa Viuda de Aldama',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'La Moraleja urbanización',
#    'country': 'es',
#    'latitude': 40.5144704,
#    'longitude': -3.634451,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/104306965/',
#    'description': 'GILMAR MORALEJA tiene el honor de presentar esta maravillosa villa provenzal en La Moraleja. Trasladarse a la Provenza francesa sin salir de Madrid es posible, gracias a esta espectacular propiedad de 10.000 m2 situada en La Moraleja.    Este chalet independiente de estilo provenzal es un verdadero paraíso de lujo y elegancia, con una superficie construida de 1.700 m2 distribuidos en dos plantas y un sótano. Al adentrarse en esta impresionante vivienda, se puede apreciar la calidad y la atención al detalle en cada rincón. Los materiales utilizados, como la piedra, la madera y el metal, crean una atmósfera lujosa y sofisticada.  El magnífico hall de entrada de 62 m2 da la bienvenida a los visitantes, mientras que el espacioso salón de 70 m2, con grandes ventanales y una imponente chimenea, se convierte en el corazón de la casa.  El comedor de 40 m2, conectado directamente con el salón, es perfecto para celebrar grandes banquetes.  Además, la propiedad cuenta con un fabuloso salón biblioteca, con majestuosas columnas de piedra, chimenea y vigas de madera vista, que lo convierten en uno de los espacios más especiales de la casa. En la planta principal también se encuentra la cocina, de estilo provenzal y completamente equipada, con despensa y zona de lavandería.  El dormitorio principal, con 21 m2, cuenta con vestidor, baño en suite y unas vistas impresionantes al jardín. En la primera planta se encuentran cinco amplias habitaciones, todas ellas con baño en suite y algunas con acceso a una terraza.  Además, hay un cuarto de estar que ofrece un espacio adicional para relajarse y disfrutar de momentos de tranquilidad. El exterior de la vivienda cuenta con un bonito porche y un jardín de una hectárea, cuidado con esmero y en perfecta armonía con la fachada de la casa. El jardín cuenta con un magnífico arbolado y una vegetación exuberante, así como una preciosa fuente. Los residentes podrán disfrutar del aire libre y de momentos de relax en este entorno idílico.   La propiedad cuenta con una piscina cubierta climatizada, perfecta para disfrutar durante todo el año en edificación individual dentro de la parcela de 10.000 m2. La Moraleja es una de las zonas más exclusivas de Madrid, conocida por sus amplias y lujosas propiedades. Este barrio residencial ofrece una gran calidad de vida, con amplias zonas verdes, seguridad privada y una gran oferta de servicios y actividades.  Además, cuenta con excelentes conexiones de transporte, con varias líneas de autobús cercanas y la estación de metro más cercana a menos de 10 kilómetros. En cuanto a la oferta educativa, La Moraleja cuenta con varios colegios de prestigio a menos de 10 kilómetros, como el International College of Spain (ICS), Colegio San Patricio, King´s College, el Liceo Europeo de Madrid y otros 10 colegios mas de altísimo prestigio.  Para ir de compras, los residentes encontrarán el Corte Inglés y el Centro Comercial Moraleja Green a pocos minutos en coche. Gilmar es una reconocida compañía inmobiliaria con más de 35 años de experiencia en el sector.  Desde 1983, Gilmar ha ayudado a sus clientes a encontrar la casa de sus sueños, ofreciendo un servicio personalizado y profesional. Si desea más información sobre esta propiedad, no dude en ponerse en contacto con nuestro equipo en la oficina de La Moraleja, ubicada en Plaza de la Moraleja, s/n. Puede llamar al o enviar un correo electrónico.  Recuerde facilitarnos la referencia MOV02961 para obtener más detalles sobre este increíble chalet en La Moraleja.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 8824.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'La Moraleja urbanización, La Moraleja',
#     'title': 'Casa independiente en paseo de la Marquesa Viuda de Aldama'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106006394',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/37/68/65/1272948906.webp',
#    'externalReference': 'VG-198000',
#    'numPhotos': 62,
#    'floor': '3',
#    'price': 1850000.0,
#    'priceInfo': {'price': {'amount': 1850000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 312.0,
#    'exterior': True,
#    'rooms': 4,
#    'bathrooms': 6,
#    'address': 'calle de Luis Martinez Feduchi',
#    'province': 'Madrid',
#    'municipality': 'La Moraleja',
#    'district': 'Encinar de los Reyes',
#    'country': 'es',
#    'latitude': 40.5001316,
#    'longitude': -3.638256,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106006394/',
#    'description': 'Gilmar Consulting Inmobiliario ofrece, espectacular piso totalmente actualizado de 312 metros, en una de las mejores urbanizaciones de El Encinar de los Reyes. Al acceder a esta exclusiva vivienda, destaca la majestuosidad de su salón- comedor, con acceso a una maravillosa terraza con vistas despejadas. Cuenta con cocina independiente, con mobiliario y electrodomésticos de primera calidad, moderna y actual; amplio office con vistas; así como tendedero techado con área de lavandería. Un aseo de cortesía completa esta estancia; así como múltiples armarios en los halls.  En el área de descanso, se distribuyen tres (en origen cuatro) fantásticos dormitorios en suite; el principal con dos baños (para él y ella), así como una preciosa terraza con vistas. Adicionalmente hay una habitación que puede funcionar de servicio o como despacho. Esta espléndida y única propiedad dispone de tres plazas de garaje, un trastero, gimnasio y una preciosa piscina. La Moraleja, compuesta por La Moraleja, El Soto y El Encinar de los Reyes, es el área residencial de lujo por excelencia de Madrid y la más conocida de España, situada en la zona Norte de Madrid. Según algunas publicaciones de prestigio mundial, es la mejor urbanización del mundo, teniendo en cuenta sus cualidades. Está situada a 15 minutos del centro y a 5 minutos de la terminal Internacional 4 del Aeropuerto Adolfo Suárez. en el término municipal de Alcobendas. La Moraleja cuenta con el mayor número de colegios privados nacionales e internacionales de toda España (entre otros el International College Spain, King’s College, San Patricio, Runnymede, Los Sauces, Brains, Santa Helena, Saint George, Highlands, Aldovea, Liceo Europeo, etc…). Acoge además uno de los dos campus que la Universidad Europea de Madrid tiene en la Comunidad de Madrid. Cuenta asimismo con varios centros comerciales y médicos, dos campos de golf de 18 hoyos, club de tenis, club de pádel, y una de las ofertas gastronómicas más atractivas de Madrid. Hay que destacar La Plaza de la Moraleja, donde se encuentran los principales y más prestigiosos restaurantes de Madrid (A’Kangas, La Máquina, Áurea, La Penela, Mati´s Bar, Sushi 99) Cafeterías (Pino), Embassy, farmacia, bancos etc… Es un área que goza de gran seguridad gracias al sistema de alarmas que está conectado con la Entidad de Conservación de La Moraleja y las garitas de seguridad ubicadas en las diferentes entradas de acceso a la zona. Vivir en la Moraleja significa calidad, exclusividad y comodidad en un entorno inigualable y con los mejores servicios.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 5929.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Encinar de los Reyes, La Moraleja',
#     'title': 'Piso en calle de Luis Martinez Feduchi'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108046286',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/79/1d/ca/1332214225.webp',
#    'externalReference': 'SG207844',
#    'numPhotos': 32,
#    'floor': '2',
#    'price': 970000.0,
#    'priceInfo': {'price': {'amount': 970000.0,
#      'currencySuffix': '€',
#      'priceDropInfo': {'formerPrice': 995000.0,
#       'priceDropValue': 25000,
#       'priceDropPercentage': 3}}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 169.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'calle de Vallehermoso',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Chamberí',
#    'country': 'es',
#    'neighborhood': 'Arapiles',
#    'latitude': 40.4388426,
#    'longitude': -3.7073215,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108046286/',
#    'description': 'En el prestigioso barrio de Vallehermoso, dentro del distrito de Chamberí, se encuentra un piso excepcional que redefine el concepto de vida urbana. Con una superficie de 169 m², esta vivienda en altura ofrece un ambiente de luminosidad y confort inigualable, gracias a su orientación suroeste que garantiza la entrada de luz natural durante todo el día. El inmueble cuenta con tres amplios dormitorios y dos baños, ideales para familias que buscan espacio y comodidad. El salón independiente proporciona un área de estar perfecta para el descanso y el entretenimiento, mientras que la cocina equipada es un espacio funcional para los amantes de la gastronomía. El piso está diseñado para el máximo confort, con calefacción central con contador individual y aire acondicionado, asegurando una temperatura ideal durante todo el año. Además, dispone de una plaza de garaje, un lujo que pocos pueden ofrecer en esta zona. La seguridad y el servicio son prioritarios, con un portero conserje que garantiza tranquilidad a los residentes. Ubicado en un edificio con ascensor, el estado de conservación del inmueble es para entrar a vivir o reformar. El piso también incluye un tendedero, lo que añade funcionalidad al día a día. Plaza de garaje no incluida en el precio a tan solo seis minutos andando de la vivienda, 39.000€. Vallehermoso es una zona que combina a la perfección la tranquilidad residencial con la vibrante vida urbana. A menos de 10 kilómetros, se encuentra el Colegio Santa María del Pilar, reconocido por su excelencia académica. Para las compras y el ocio, el Centro Comercial Moda Shopping es una opción cercana y completa. En cuanto a transporte público, las líneas de metro más cercanas son Islas Filipinas (Línea 7) y Moncloa (Líneas 3 y 6), y las líneas de autobuses que pasan por la zona incluyen el 16 y el 61, entre otras, facilitando el acceso a cualquier punto de la ciudad. Desde 1983, GILMAR se ha dedicado a ayudar a sus clientes a encontrar la casa de sus sueños, ofreciendo un servicio personalizado y de calidad. Con una trayectoria impecable, GILMAR se ha consolidado como líder en el sector inmobiliario, combinando experiencia y dedicación para satisfacer las necesidades de cada cliente. Para más información sobre este inmueble, por favor, contacta con nuestro equipo de Chamberí - Argüelles en C/ Carranza, 20, llamando al o escribiendo a. No olvides mencionar la referencia 207844 para que podamos asistirte de manera más eficiente.',
#    'hasVideo': True,
#    'status': 'renew',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': False,
#     'parkingSpacePrice': 39000.0},
#    'priceByArea': 5740.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Arapiles, Madrid',
#     'title': 'Piso en calle de Vallehermoso'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108324155',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/ca/0a/25/1344500754.webp',
#    'externalReference': 'AG210112',
#    'numPhotos': 41,
#    'floor': '4',
#    'price': 895000.0,
#    'priceInfo': {'price': {'amount': 895000.0, 'currencySuffix': '€'}},
#    'propertyType': 'penthouse',
#    'operation': 'sale',
#    'size': 106.0,
#    'exterior': True,
#    'rooms': 2,
#    'bathrooms': 1,
#    'address': 'calle de las Aguas',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Centro',
#    'country': 'es',
#    'neighborhood': 'Palacio',
#    'latitude': 40.4120656,
#    'longitude': -3.7117231,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108324155/',
#    'description': '**Exclusivo ático en el emblemático barrio de Palacio, Madrid**  Descubre este magnífico ático de 98m2 en uno de los enclaves más históricos y codiciados de Madrid. Este elegante inmueble cuenta con 2 dormitorios, 2 baños, una cocina completamente equipada y un salón independiente bañado por luz natural gracias a su orientación este. Su diseño exterior y su impecable estado de conservación lo convierten en un refugio perfecto para quienes buscan un hogar sofisticado y listo para entrar a vivir.  La finca, construida en 1940, es un ejemplo de arquitectura clásica madrileña y ha sido cuidadosamente mantenida para preservar su encanto original. Dispone de ascensor, calefacción individual de gas natural y aire acondicionado, proporcionando el máximo confort durante todo el año. El suelo de parquet y los acabados de alta calidad refuerzan la sensación de lujo y calidez.  Ubicado en pleno distrito Centro, a pocos pasos de lugares icónicos como el Palacio Real, la Plaza Mayor y la Catedral de la Almudena. Además, la zona ofrece una amplia oferta gastronómica, con tabernas tradicionales y restaurantes de alta cocina, así como teatros, galerías de arte y boutiques exclusivas.  El barrio también cuenta con una excelente conectividad. A menos de 500 metros se encuentran las estaciones de metro de Ópera (líneas 2, 5 y R) y La Latina (línea 5), además de varias líneas de autobús como la 31, 50 y 65. Para quienes prefieren el tren de cercanías, la estación de Príncipe Pío está a solo 1,5 kilómetros. A nivel educativo, el prestigioso Colegio San Ildefonso está a menos de 2 kilómetros, y en cuanto a compras, el Centro Comercial Príncipe Pío ofrece una amplia variedad de tiendas y servicios.  Desde 1983, en GILMAR nos hemos dedicado a ayudar a nuestros clientes a encontrar la casa de sus sueños, ofreciendo un servicio integral y personalizado. Somos referentes en el sector inmobiliario gracias a nuestra experiencia, profesionalidad y compromiso.  Para más información sobre este exclusivo ático, no dudes en contactar con nuestro equipo de la oficina de Centro. Estamos situados en Plaza de Herradores, 4, y puedes llamarnos al ** ** o escribirnos a ****. Por favor, facilita la referencia **210112** para que podamos atenderte de manera más eficiente. ¡Tu nuevo hogar te espera!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 8443.0,
#    'change': {},
#    'detailedType': {'typology': 'flat', 'subTypology': 'penthouse'},
#    'suggestedTexts': {'subtitle': 'Palacio, Madrid',
#     'title': 'Ático en calle de las Aguas'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '105036254',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/58/39/8c/1302328500.webp',
#    'externalReference': 'GH196907',
#    'numPhotos': 48,
#    'floor': '2',
#    'price': 1495000.0,
#    'priceInfo': {'price': {'amount': 1495000.0, 'currencySuffix': '€'}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 164.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 3,
#    'address': 'calle de Noblejas',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Centro',
#    'country': 'es',
#    'neighborhood': 'Palacio',
#    'latitude': 40.4153152,
#    'longitude': -3.7138457,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/105036254/',
#    'description': '¡Exclusivo Piso en Venta en el Corazón de Madrid! Este impresionante piso de 164 m² combina elegancia, confort y una ubicación inmejorable, ideal para quienes buscan vivir en una vivienda de alta calidad y con historia. Además, ha sido completamente reformado y está listo para estrenar, con acabados y mobiliario totalmente nuevos que garantizan calidad, funcionalidad y un estilo impecable. Alojado en un magnífico edificio en el corazón de Madrid, construido en 1834 y con casi dos siglos de historia, este inmueble aporta un carácter y un valor patrimonial únicos a la propiedad. El apartamento ha sido reformado con las más altas calidades, asegurando durabilidad y un acabado personalizado perfecto. La reforma incluye detalles de lujo como persianas eléctricas que ofrecen ventajas como mayor comodidad, seguridad, eficiencia energética y un valor estético y funcional añadido. El luminoso salón, corazón de la vivienda, cuenta con tres encantadores balcones que permiten la entrada de abundante luz natural y ofrecen vistas privilegiadas de la zona. La cocina abierta con península, equipada con electrodomésticos de última generación y acabados de alta calidad, es perfecta para los amantes de la gastronomía y las reuniones con amigos y familiares. El piso dispone de tres habitaciones espaciosas, incluyendo una habitación principal con baño en suite, creando un oasis privado para descansar y relajarse. Las otras dos habitaciones son versátiles, ideales para dormitorios adicionales, una oficina en casa o espacios para invitados. Todas ellas comparten un baño completo moderno y funcional, además de un aseo de cortesía elegante y práctico para mayor comodidad. El confort está garantizado con suelo de piedra de Campaspero, que ofrece excelentes ventajas para su uso en suelos radiantes: buena conductividad térmica, capacidad de retención de calor, durabilidad, estética atractiva y facilidad de mantenimiento. La calefacción por suelo radiante y el aire acondicionado por conductos aseguran una temperatura agradable durante todo el año. Las puertas interiores en altura, hechas a medida, aportan un ambiente amplio y lujoso, mejoran la circulación del aire y la accesibilidad, además de potenciar la estética del espacio. Las luces dimables permiten crear ambientes personalizados, contribuyendo a la sostenibilidad ambiental y al bienestar del hogar. El inmueble también cuenta con una chimenea que aporta calidez, confort y un toque de elegancia, transformando cualquier espacio en un lugar más acogedor y funcional. Vive en una ubicación exclusiva, con fácil acceso a sitios históricos, parques, tiendas y restaurantes. Además, la finca está exenta de pagar IBI por ser un edificio protegido, lo que representa un ahorro significativo en gastos anuales. ¡No pierdas la oportunidad de vivir en uno de los barrios más emblemáticos de Madrid!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 9116.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Palacio, Madrid',
#     'title': 'Piso en calle de Noblejas'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '106751275',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/57/2a/4b/1319043313.webp',
#    'externalReference': 'PV8826I',
#    'numPhotos': 82,
#    'price': 9000000.0,
#    'priceInfo': {'price': {'amount': 9000000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 1674.0,
#    'rooms': 9,
#    'bathrooms': 10,
#    'address': 'calle Eibar',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Moncloa',
#    'country': 'es',
#    'neighborhood': 'El Plantío',
#    'latitude': 40.469054,
#    'longitude': -3.8103585,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/106751275/',
# ...
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 5455.0,
#    'change': {},
#    'detailedType': {'typology': 'flat', 'subTypology': 'penthouse'},
#    'suggestedTexts': {'subtitle': 'Virgen del Cortijo - Manoteras, Madrid',
#     'title': 'Ático'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '107568319',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/b9/58/48/1316435802.webp',
#    'externalReference': 'W-02YO9N',
#    'numPhotos': 43,
#    'price': 1850000.0,
#    'priceInfo': {'price': {'amount': 1850000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 300.0,
#    'rooms': 4,
#    'bathrooms': 4,
#    'address': 'avenida del Levante',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Chamartín',
#    'country': 'es',
#    'neighborhood': 'Bernabéu-Hispanoamérica',
#    'latitude': 40.4580257,
#    'longitude': -3.666001,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/107568319/',
#    'description': 'Chalet pareado para reforma en Chamartín Engel & Völkers presenta este chalet pareado, para reformar, con tres plantas construidas en una parcela rectangular de 184 m2, situado en una tranquila colonia histórica de Chamartín.  La primera planta, de 75 m2 de superficie, cuenta con tres salones, cocina y baño de cortesía. Sus techos de 3,6 m. de altura ofrecen una gran amplitud. En la segunda planta, de 50 m2 y techos de madera, se encuentran tres dormitorios con armarios empotrados y un baño completo.  En la tercera planta, un espacio diáfano de 50 m2 con suelo radiante, se sitúa el dormitorio principal con salida a una terraza con vistas al jardín trasero y un baño completo. La vivienda dispone de aire acondicionado en las principales estancias. La entrada a la propiedad cuenta con un jardín arbolado, aparcamiento para un vehículo y un pequeño sótano. En el jardín posterior, se encuentran la estructura de la piscina a falta del recubrimiento interior y la maquinaria para su funcionamiento, y un cuarto de baño.  Las superficies construidas de las plantas, la terraza, jardines y los espacios del garaje, trastero y sótano suman un total de unos 300 m2 aproximadamente. Además, la vivienda dispone de un algibe con capacidad para 9.000 litros de agua de lluvia. Una propiedad ideal para quienes buscan amplitud, calidad y opciones de personalización en una de las mejores zonas de Chamartín. ¡No pierda la oportunidad de visitarla!. Esta propiedad se ubica en una colonia de viviendas unifamiliares del barrio de Hispanoamérica, en el distrito de Chamartín, al norte de la capital. Una zona segura y apacible, ideal para familias, con zonas verdes y bien comunicada, con cómodo acceso a la M-30, a 15 minutos en coche del Aeropuerto y la Estación de Chamartín, y a unos 30 minutos andando del estadio Bernabéu. Chamartín ofrece una amplia gama de servicios, desde grandes almacenes, comercios, farmacias, escuelas infantiles, colegios, centros de estudios superiores, iglesias, gimnasios y zonas deportivas, hoteles, etc., hasta una selección de los mejores bares y restaurantes de Madrid. Chamartín alberga también distintas Embajadas e importantes Edificios Públicos, y es sede de varias de las empresas españolas y entidades financieras más relevantes. El sistema de transporte público asegura la máxima comodidad para los residentes de sus barrios, ya que actualmente disponen de unas 50 líneas de autobús, 7 líneas de metro y dos estaciones de cercanías. La línea 8 de metro conecta directamente el intercambiador de Nuevos Ministerios con el Aeropuerto de Madrid-Barajas Adolfo Suárez. La estación de Chamartín es también terminal para la mayoría de trenes de media y larga distancia hacia el norte y este de España.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 6167.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Bernabéu-Hispanoamérica, Madrid',
#     'title': 'Casa independiente en avenida del Levante'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '108552407',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/23/c2/70/1348241483.webp',
#    'externalReference': 'W-0306LR',
#    'numPhotos': 68,
#    'price': 1400000.0,
#    'priceInfo': {'price': {'amount': 1400000.0, 'currencySuffix': '€'}},
#    'propertyType': 'chalet',
#    'operation': 'sale',
#    'size': 539.0,
#    'rooms': 6,
#    'bathrooms': 3,
#    'address': 'calle Nuestra Señora de Nuria',
#    'province': 'Madrid',
#    'municipality': 'Pozuelo de Alarcón',
#    'district': 'Zona Estación',
#    'country': 'es',
#    'neighborhood': 'Zona Estación',
#    'latitude': 40.4404198,
#    'longitude': -3.7987573,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/108552407/',
#    'description': 'Interesante unifamiliar en Pozuelo con múltiples posibilidades. Engel & Völkers ofrece una magnífica propiedad unifamiliar, ubicada en una zona residencial de Pozuelo. Se trata de una casa de dos plantas más semisótano diáfano, con 180m2 cada nivel, y con entradas independientes desde el jardín. Lo que permite su uso como viviendas autónomas o su transformación en una única residencia familiar de gran amplitud. Su estética de estilo mid-century confiere a toda la propiedad su carácter especial y su valor más atractivo. La planta principal se utiliza actualmente como "casa de invierno". En este nivel se encuentra el núcleo más tradicional del hogar: un amplio salón con grandes ventanales a la terraza; la cocina funcional y espaciosa; cuatro dormitorios y dos baños completos. Una bonita escalera interior de madera la comunica con la "casa de verano" de la planta cero, a nivel del jardín. La generosa terraza aporta no sólo la entrada abundante de luz natural, sino también una orientación ideal para disfrutar del sol de invierno, y la personalidad mid-century de toda la propiedad. Esta casa de invierno tiene su propio acceso al jardín desde la terraza a través de una escalera de piedra, también con marcado estilo cincuenta. La segunda planta fue pensada como refugio ideal para los meses más cálidos de Madrid. Diseñada como vivienda independiente, ofrece un gran salón protegido del sol del verano por el porche exterior creado por la terraza de la planta principal. Zona que ofrece un espacio magnífico para disfrutar del jardín en las noches de verano. Por supuesto, cuenta con cocina con una amplia despensa que puede integrarse, para crear un espacio moderno y funcional. El dormitorio principal cuenta con baño en suite, y una habitación adicional que puede reconvertirse en gran vestidor. Además cuenta con otro amplio dormitorio conectado con el salón. Esta planta tiene acceso directo al garaje donde se ubica un moderno ascensor. El sótano ofrece un espacio diáfano perfecto para uso profesional, estudio artístico o taller de hobbies como cerámica, escultura, o costura. Su acceso directo al jardín la hacen ideal para una actividad de clientes o visitas externas, con entrada totalmente independiente. Extras y potencial La propiedad cuenta con un ascensor moderno recién instalado, que conecta desde el amplio garaje (capacidad para tres vehículos) hasta las dos plantas principales. El jardín privado cuenta con una amplia piscina y una zona deportiva, en una parcela que ofrece privacidad y tranquilidad. La distribución actual permite múltiples posibilidades: Convertirla en una única vivienda familiar con zonas diferenciadas. Reformar y mantener su estructura actual para alquilar por plantas. Atraer el interés de promotores e inversores para realizar una obra nueva con posibilidad de construir un pareado; o un bajo con jardín, y un piso con espectacular terraza para alquiler. Una propiedad singular, con encanto, funcionalidad y alto potencial de rentabilidad. Una oportunidad única en Pozuelo para vivir, invertir o desarrollar. Pozuelo de Alarcón es una localidad en el Noroeste de la Comunidad de Madrid. Su enclave privilegiado por su proximidad a la capital, sus amplias zonas verdes y jardines, y sus servicios de calidad (Colegios y Universidades, Hoteles, Centros Comerciales de lujo, Hospitales privados de reconocido prestigio) han hecho que sea elegida como lugar de residencia por sectores de gran nivel adquisitivo, profesional y cultural de la sociedad madrileña. Posee excelentes comunicaciones con el centro y sus alrededores a través de: autovías y carreteras (M-30, M-40, M-503 y A-6); estaciones de Cercanías (Pozuelo y El Barrial, líneas C-7 y C-10); y líneas de autobuses urbanos e interurbanos (560, 561, 561A, 561B, 5 56A, y los nocturnos N901, N902, N905 y N906). Sin olvidar las líneas especiales A y H que enlazan al campus.',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'parkingSpace': {'hasParkingSpace': True,
#     'isParkingSpaceIncludedInPrice': True},
#    'priceByArea': 2597.0,
#    'change': {},
#    'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'},
#    'suggestedTexts': {'subtitle': 'Zona Estación, Pozuelo de Alarcón',
#     'title': 'Casa independiente en calle Nuestra Señora de Nuria'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': True,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True},
#   {'propertyCode': '107526421',
#    'thumbnail': 'https://img4.idealista.com/blur/480_360_mq/0/id.pro.es.image.master/65/eb/31/1315425480.webp',
#    'externalReference': 'GH202391',
#    'numPhotos': 44,
#    'floor': '3',
#    'price': 920000.0,
#    'priceInfo': {'price': {'amount': 920000.0,
#      'currencySuffix': '€',
#      'priceDropInfo': {'formerPrice': 980000.0,
#       'priceDropValue': 60000,
#       'priceDropPercentage': 6}}},
#    'propertyType': 'flat',
#    'operation': 'sale',
#    'size': 146.0,
#    'exterior': True,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'calle de las Fuentes',
#    'province': 'Madrid',
#    'municipality': 'Madrid',
#    'district': 'Centro',
#    'country': 'es',
#    'neighborhood': 'Sol',
#    'latitude': 40.4167924,
#    'longitude': -3.7074916,
#    'showAddress': False,
#    'url': 'https://www.idealista.com/inmueble/107526421/',
#    'description': 'GILMAR Consulting Inmobiliario presenta, en exclusiva, elegante vivienda en el barrio de Palacio. Con una superficie construida de 146 m2, dispone de 3 dormitorios y 2 cuartos de baños completos, además de amplio vestidor en el dormitorio principal. Situada en una ubicación privilegiada, la vivienda se encuentra rodeada de todo tipo de comodidades y servicios en la zona. El inmueble destaca por su luminosidad gracias a su orientación sureste, lo que permite disfrutar de una gran cantidad de luz natural durante todo el día. Además, cuenta con cuatro balcones a la calle con impresionantes vistas al centro de la ciudad. La vivienda ha sido completamente reformada con materiales de primera calidad: los suelos de parquet y la carpintería interior de madera natural aportan un toque de elegancia y calidez. La cocina, con una isla central y electrodomésticos integrados, es el lugar perfecto para los amantes de la cocina. Además, el centro comercial más cercano es Plaza de Isabel Segunda, donde se pueden encontrar una gran variedad de tiendas, restaurantes y servicios de ocio. También hay varias líneas de metro cercanas, como la estación de Metro Ópera, a solo 1 minuto a pie, que conecta con el resto de la ciudad de manera rápida y eficiente. El barrio de Palacio es conocido por su historia y encanto. Está situado junto al Palacio Real y la Plaza de Oriente, lo que lo convierte en un lugar ideal para aquellos que buscan vivir en un entorno lleno de cultura y tradición. Además, cuenta con una amplia oferta de restaurantes, bares y tiendas exclusivas que hacen de esta zona un lugar vibrante y lleno de vida. En cuanto al transporte público, las líneas de autobús más cercanas a la ubicación del inmueble son la línea 3 y la línea 148, que ofrecen conexiones a diferentes partes de la ciudad. GILMAR es una reconocida compañía inmobiliaria con una amplia experiencia en el sector. Desde 1983, hemos estado ayudando a nuestros clientes a encontrar la casa de sus sueños. Nuestro equipo de expertos en marketing inmobiliario se dedica a ofrecer descripciones detalladas y atractivas de cada propiedad, destacando sus características únicas y su ubicación privilegiada. Si estás interesado en obtener más información sobre este impresionante piso en Palacio, por favor, no dudes en contactarnos y facilitarnos la referencia del inmueble. Nuestro equipo estará encantado de ayudarte y proporcionarte todos los detalles que necesites para tomar la mejor decisión. Puedes visitarnos en nuestra oficina en Plaza de Herradores, 4 o llamarnos al ¡Esperamos poder ayudarte a encontrar tu nuevo hogar!',
#    'hasVideo': True,
#    'status': 'good',
#    'newDevelopment': False,
#    'hasLift': True,
#    'priceByArea': 6301.0,
#    'change': {},
#    'detailedType': {'typology': 'flat'},
#    'suggestedTexts': {'subtitle': 'Sol, Madrid',
#     'title': 'Piso en calle de las Fuentes'},
#    'hasPlan': True,
#    'has3DTour': True,
#    'has360': False,
#    'hasStaging': False,
#    'highlight': {'groupDescription': 'Top+'},
#    'savedAd': {},
#    'notes': [],
#    'topNewDevelopment': False,
#    'topPlus': True}],
#  'total': 22545,
#  'totalPages': 451,
#  'actualPage': 1,
#  'itemsPerPage': 50,
#  'numPaginations': 0,
#  'summary': ['Comprar',
#   'Casas y pisos',
#   'Madrid provincia',
#   'Todos los precios',
#   'Todos los tamaños'],
#  'filter': {'locationName': 'Madrid'},
#  'alertName': 'Viviendas en Madrid',
#  'totalAppliedFilters': 0,
#  'lowerRangePosition': 0,
#  'upperRangePosition': 50,
#  'paginable': True}

# %%
token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTc1Mzc2NTIxMywiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiNzE4NzFmYzItMDM4Yi00ZGRhLTg5ZTEtYmEwOTg2Yzg5Y2ZjIiwiY2xpZW50X2lkIjoidDV5aXMzdWM5bm9iZm1lMHVxYXEwN2JieGhzNmIyd28ifQ.UaG65ODSJNJTPaYvzu4aRcgEbAetpH932iKGiepvIsg'
