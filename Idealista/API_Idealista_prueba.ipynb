# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("api_key")
secret = os.getenv("secret")

# %%
from utils_idealista import idealista_token, query
import pandas as pd


for num_page in range(401,510):
    filter_request = {
        "country": "es",
        "operation": "sale",
        "propertyType": "homes",
        "locationId": "0-EU-ES-28",
        "maxItems": 50,
        "numPage": num_page
    }
    token, expires = idealista_token(api_key, secret)
    print(token)
    response = query(token, filter_request)

    # Lista de viviendas dentro del JSON
    viviendas = response["elementList"]

    # Usamos json_normalize con sep='.' para que las claves anidadas se aplanen con ese separador
    df = pd.json_normalize(viviendas, sep='.')

    df.to_csv(f"datos/datos_pag_{num_page}.csv", index=False)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTc1NDQ1MzA0NSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiNGY0YmFhMzItNDY1Yi00ZTkwLTkwMDctZDA3YTJkMzdlMTM2IiwiY2xpZW50X2lkIjoiZTZ0OHEzbG41ZDg4dnBoOHhnZ202NXowdjg2aGI1c2MifQ.1uKLNJmIC7lmaAQUY9G6Safb8og-r_w5_9WzRwjtwnk
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTc1NDQ1MzA0NSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiZmIyYTJlNDAtM2FkZS00NWVjLThjZTUtNTkzYzkwZTIxYjUxIiwiY2xpZW50X2lkIjoiZTZ0OHEzbG41ZDg4dnBoOHhnZ202NXowdjg2aGI1c2MifQ.c3_F1RhH-wZ-WT8Jt_v0_vvvaG_3pP9t0evd2UUNnlA
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTc1NDQ1MzA0NiwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiY2U2YjgyZDktYjNhOS00ZTM0LTk1ZTUtNTlmYWEzMWJhYjVmIiwiY2xpZW50X2lkIjoiZTZ0OHEzbG41ZDg4dnBoOHhnZ202NXowdjg2aGI1c2MifQ.V7R2K-Uu1p2FX4c8iDNbndyQuhEiV_PTZQmOthUPfW0
# ...
